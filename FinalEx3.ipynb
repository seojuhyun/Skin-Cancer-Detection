# %% [markdown]
# # VIT(vision transformer)

# %% [markdown]
# https://haystar.tistory.com/95
#
# https://ivelopalways.tistory.com/entry/Deep-Learning-%EB%85%BC%EB%AC%B8-%EB%A6%AC%EB%B7%B0-Vision-TransformerViT-An-Image-is-Worth-16x16-Words-Transformers-for-Image-Recognition-at-Scale#google_vignette
#
# DATASET
# https://www.kaggle.com/competitions/isic-2024-challenge/data

# %% [markdown]
# # Data Processing

# %%
import os
import shutil
import pandas as pd

# 경로 설정
image_dir = './isic-2024-challenge/train-image/image'
meta_csv = './isic-2024-challenge/train-metadata.csv'
output_root = 'converted-dataset/train'

# 메타데이터 로드
df = pd.read_csv(meta_csv)

for idx, row in df.iterrows():
    isic_id = row['isic_id']
    label = str(row['target'])

    # 입력 이미지 경로
    src_path = os.path.join(image_dir, f"{isic_id}.jpg")
    # 저장할 클래스 폴더
    save_dir = os.path.join(output_root, f"class{label}")
    os.makedirs(save_dir, exist_ok=True)
    # 출력 이미지 경로
    dst_path = os.path.join(save_dir, f"{isic_id}.jpg")

    try:
        shutil.copyfile(src_path, dst_path)
    except Exception as e:
        print(f" 복사 실패: {src_path} → {dst_path} : {e}")

# %%
import h5py
import pandas as pd
import numpy as np
import os
from PIL import Image
from io import BytesIO

# 경로
hdf5_path = './isic-2024-challenge/test-image.hdf5'
meta_csv = './isic-2024-challenge/test-metadata.csv'
output_dir = 'converted-dataset/test'
os.makedirs(output_dir, exist_ok=True)

# 메타데이터 로드
df = pd.read_csv(meta_csv)

# HDF5에서 이미지 추출
with h5py.File(hdf5_path, 'r') as hdf:
    for idx, row in df.iterrows():
        isic_id = row['isic_id']

        try:
            raw = hdf[isic_id][()]  # shape: [[b'\xff\xd8...']]
            if isinstance(raw, (np.ndarray, list)):
                raw = raw[0]
            img = Image.open(BytesIO(raw))
            img.save(os.path.join(output_dir, f"{isic_id}.jpg"))
        except Exception as e:
            print(f"❌ {isic_id} 변환 실패: {e}")

# %%
#----------------------------------------------------------------------------

# %%
# 값만 확인
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
from torchsummary import summary


x = Image.open('./converted-dataset/train/class0/ISIC_0015670.jpg')
x = x.resize((288,288))
tf_toTensor = ToTensor() 
x = tf_toTensor(x)
x = torch.unsqueeze(x,0) #배치 크기 맞춰줌
x.shape
# Out:
# torch.Size([1, 3, 288, 288])

# %%
x = torch.randn(64,3,288,288)

# %%
P = 18
N = int(288*288/(18*18)) #256

"""
기존의 B*C*H*W의 차원을 B*N*(P*P*C)로 바꿔줘야함

einops의 rearrange 함수를 이용하여 이미지를 패치로 나누고 flatten을 한번에 수행할 수 있다.
"""

patches = rearrange(x, 'b c (h s1) (w s2) -> b (h w) (s1 s2 c)', s1=P, s2=P) #[1,N,P*P*c\]

# %%
patches.shape
# Out:
# torch.Size([64, 256, 972])

# %%
P= 18
in_channels =3
emb_size =128

projection = nn.Sequential(
    nn.Conv2d(3,P*P*in_channels, kernel_size=P, stride=P),
    Rearrange('b e (h) (w) -> b (h w) e'),
    nn.Linear(P*P*in_channels, emb_size)
    
)
projection(x).shape
# Out:
# torch.Size([64, 256, 128])

# %%
emb_size = 128
img_size = 288
patch_size = 18

#이미지를 패치사이즈로 나누고 flatten
proj_x = projection(x)
print("Projected X shape : ", proj_x.shape)

#cls_token과 positional encoding parameter 선언
cls_token = nn.Parameter(torch.randn(1,1,emb_size))
positions = nn.Parameter(torch.randn((img_size//patch_size)**2+1, emb_size))
print("Cls shape : ", cls_token.shape)
print("Pos shape : ", positions.shape)

#cls_token을 배치사이즈만큼 확장
batch_size = 64
cls_tokens = repeat(cls_token, '() n e -> b n e', b=batch_size)
print("Repeated Cls shape : ", cls_tokens.shape)

#cls_token과 proj_x를 concatenate
cat_x = torch.cat([cls_tokens, proj_x], dim=1)
print("Cls+proj_x : ", cat_x.shape)

#position encoding을 더해줌
cat_x += positions

print("Output : ", cat_x.shape)
# Out:
# Projected X shape :  torch.Size([64, 256, 128])
# Cls shape :  torch.Size([1, 1, 128])
# Pos shape :  torch.Size([257, 128])
# Repeated Cls shape :  torch.Size([64, 1, 128])
# Cls+proj_x :  torch.Size([64, 257, 128])
# Output :  torch.Size([64, 257, 128])

# %%
#---------------------

# %%
# >> PatchEmbedding, 파라미터는 직접 계산해서 지정함
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
from torchsummary import summary


import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
from torchsummary import summary

class PatchEmbedding(nn.Module):
    def __init__(self, in_channels: int = 3, patch_size: int = 18, emb_size: int = 128, img_size: int = 288):
        self.patch_size = patch_size
        super().__init__()
        # patch embedding
        self.projection = nn.Sequential(
            # using a conv layer instead of a linear one -> performance gains
            nn.Conv2d(in_channels, patch_size*patch_size*in_channels, kernel_size=patch_size, stride=patch_size),
            Rearrange('b e (h) (w) -> b (h w) e'),
            nn.Linear(patch_size*patch_size*in_channels, emb_size)
        )
        
        # nn.Parameter = 학습 가능한 파라미터로 설정하는 것
        # Add CLS Token
        self.cls_token = nn.Parameter(torch.randn(1,1, emb_size))
        
        # position embedding
        self.positions = nn.Parameter(torch.randn((img_size // patch_size) **2 + 1, emb_size))


    def forward(self, x: Tensor) -> Tensor:
        b, _, _, _ = x.shape
        x = self.projection(x)
        cls_tokens = repeat(self.cls_token, '() n e -> b n e', b=b)  # cls token을 x의 첫번째 차원으로 반복

        # prepend the cls token to the input
        x = torch.cat([cls_tokens, x], dim=1)
        
        # add position embedding
        x += self.positions
        return x

# %%
embed = PatchEmbedding()
x = embed(x)

# %%
x.shape   #([8, 256, 972])
# Out:
# torch.Size([64, 257, 128])

# %%
summary(embed, (3, 288, 288), device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 972, 16, 16]         945,756
#          Rearrange-2             [-1, 256, 972]               0
#             Linear-3             [-1, 256, 128]         124,544
# ================================================================
# Total params: 1,070,300
# Trainable params: 1,070,300
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.95
# Forward/backward pass size (MB): 4.05
# Params size (MB): 4.08
# Estimated Total Size (MB): 9.08
# ----------------------------------------------------------------

# %%
#----------------------------------------------------
emb= 128
num_heads =8  

#k,q,v 입력 Linear embedding=> Linear projection
keys= nn.Linear(emb,emb)
queries = nn.Linear(emb,emb)
values =nn.Linear(emb,emb)

#Linear projection을 거친 q,k,v를 8 개의 head로 나눔
queries = rearrange(queries(x), 'b n (h d) -> b h n d', h=num_heads)
keys = rearrange(keys(x), 'b n (h d) -> b h n d', h=num_heads)
values = rearrange(values(x), 'b n (h d) -> b h n d', h=num_heads)

queries.shape, keys.shape, values.shape
# Out:
# (torch.Size([64, 8, 257, 16]),
#  torch.Size([64, 8, 257, 16]),
#  torch.Size([64, 8, 257, 16]))

# %%
# queries * keys
# Q.matmul(K.T)
emb_size= 128   # 972

energy = torch.einsum('bhqd, bhkd -> bhqk', queries, keys)
print("energy : ",energy.shape)

#Get attention score
scaling = emb_size**(1/2)
att = F.softmax(energy, dim=-1)/scaling
print("att : ", att.shape)

#Attention score * Values
out = torch.einsum('bhal, bhlv -> bhav',att, values)
print("out : ", out.shape)

#Rearrange to emb_size (concatenate)
out = rearrange(out, "b h n d -> b n (h d)")
print("out2 : ", out.shape)
#---------------------------------------------------------------------
# Out:
# energy :  torch.Size([64, 8, 257, 257])
# att :  torch.Size([64, 8, 257, 257])
# out :  torch.Size([64, 8, 257, 16])
# out2 :  torch.Size([64, 257, 128])

# %%
# >> Transformer Encoder

import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
from torchsummary import summary


## Multihead attention.
class MultiHeadAttention(nn.Module):
    def __init__(self, emb_size: int = 128, num_heads: int = 8, dropout: float = 0):
        super().__init__()
        self.emb_size = emb_size
        self.num_heads = num_heads
        # fuse the queries, keys and values in one matrix
        self.qkv = nn.Linear(emb_size, emb_size * 3)
        self.att_drop = nn.Dropout(dropout)
        self.projection = nn.Linear(emb_size, emb_size)
        
    def forward(self, x : Tensor, mask: Tensor = None) -> Tensor:
        # split keys, queries and values in num_heads
        qkv = rearrange(self.qkv(x), "b n (h d qkv) -> (qkv) b h n d", h=self.num_heads, qkv=3)
        queries, keys, values = qkv[0], qkv[1], qkv[2]
        # sum up over the last axis
        energy = torch.einsum('bhqd, bhkd -> bhqk', queries, keys) # batch, num_heads, query_len, key_len
        #print("energy : ",energy.shape)
        
        if mask is not None:
            fill_value = torch.finfo(torch.float32).min
            energy.mask_fill(~mask, fill_value)
            
        scaling = self.emb_size ** (1/2)   # Get attention score
        att = F.softmax(energy, dim=-1) / scaling
        att = self.att_drop(att)
        #print("att : ", att.shape)
        
        # sum up over the third axis
        out = torch.einsum('bhal, bhlv -> bhav ', att, values)   #Attention score * Values
        #print("out : ", out.shape)

        out = rearrange(out, "b h n d -> b n (h d)")   #Rearrange to emb_size (concatenate)
        #print("out2 : ", out.shape)
        out = self.projection(out)
        return out
    



# Residuals
class ResidualAdd(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn
        
    def forward(self, x, **kwargs):
        res = x
        x = self.fn(x, **kwargs)
        x += res
        return x


# MLP layer
# 기타사항, nn.Sequential 임으로 굳이 def forward 쓸 필요가 없음.
class FeedForwardBlock(nn.Sequential):
    def __init__(self, emb_size: int, expansion: int = 4, drop_p: float = 0.):
        super().__init__(
            nn.Linear(emb_size, expansion * emb_size),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(expansion * emb_size, emb_size),
        )

# %%
# >> Transformer Encoder Block

## load custom module ============> 따로 불러오기
#from layers.Multihead_attention import MultiHeadAttention, ResidualAdd, FeedForwardBlock
#from layers.patch_embedding import PatchEmbedding


class TransformerEncoderBlock(nn.Sequential):
    def __init__(self,
                 emb_size: int = 128,
                 drop_p: float = 0.,
                 forward_expansion: int = 4,
                 forward_drop_p: float = 0.,
                 ** kwargs):
        super().__init__(
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                MultiHeadAttention(emb_size, **kwargs),
                nn.Dropout(drop_p)
            )),
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                FeedForwardBlock(
                    emb_size, expansion=forward_expansion, drop_p=forward_drop_p),
                nn.Dropout(drop_p)
            )
            ))
        
class TransformerEncoder(nn.Sequential):
    def __init__(self, depth: int = 7, **kwargs):
        super().__init__(*[TransformerEncoderBlock(**kwargs) for _ in range(depth)])

# %%
#-------------------------------------------------
x = torch.randn(64,3,288,288)
patches_embedded = PatchEmbedding()(x)
TransformerEncoderBlock()(patches_embedded).shape
#-------------------------------------------------------
# Out:
# torch.Size([64, 257, 128])

# %%
# >> Make MLP Head
from einops.layers.torch import Rearrange, Reduce

class ClassificationHead(nn.Sequential):
    def __init__(self, emb_size: int = 128, n_classes: int = 2):
        super().__init__(
            Reduce('b n e -> b e', reduction='mean'),
            nn.LayerNorm(emb_size), 
            nn.Linear(emb_size, n_classes))

# %%
# >> 학습 코드
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import torch.optim as optim
import os

from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
from torchsummary import summary
from torch.utils.data import random_split


# load custom module
#from layers.patch_embedding import PatchEmbedding
#from layers.Mlp_head import ClassificationHead
#from layers.Earlystopping import EarlyStopping
#from block.Encoder_Block import TransformerEncoder
#from PIL import Image

class ViT(nn.Sequential):
    def __init__(self,     
                in_channels: int = 3,
                patch_size: int = 18,
                emb_size: int = 128,
                img_size: int = 288,
                depth: int = 8,
                n_classes: int = 2,
                **kwargs):
        super().__init__(
            PatchEmbedding(in_channels, patch_size, emb_size, img_size),
            TransformerEncoder(depth, emb_size=emb_size, **kwargs),
            ClassificationHead(emb_size, n_classes)
        )

# %%
summary(ViT(), (3,288,288), device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 972, 16, 16]         945,756
#          Rearrange-2             [-1, 256, 972]               0
#             Linear-3             [-1, 256, 128]         124,544
#     PatchEmbedding-4             [-1, 257, 128]               0
#          LayerNorm-5             [-1, 257, 128]             256
#             Linear-6             [-1, 257, 384]          49,536
#            Dropout-7          [-1, 8, 257, 257]               0
#             Linear-8             [-1, 257, 128]          16,512
# MultiHeadAttention-9             [-1, 257, 128]               0
#           Dropout-10             [-1, 257, 128]               0
#       ResidualAdd-11             [-1, 257, 128]               0
#         LayerNorm-12             [-1, 257, 128]             256
#            Linear-13             [-1, 257, 512]          66,048
#              GELU-14             [-1, 257, 512]               0
#           Dropout-15             [-1, 257, 512]               0
#            Linear-16             [-1, 257, 128]          65,664
#           Dropout-17             [-1, 257, 128]               0
#       ResidualAdd-18             [-1, 257, 128]               0
#         LayerNorm-19             [-1, 257, 128]             256
#            Linear-20             [-1, 257, 384]          49,536
#           Dropout-21          [-1, 8, 257, 257]               0
#            Linear-22             [-1, 257, 128]          16,512
# MultiHeadAttention-23             [-1, 257, 128]               0
#           Dropout-24             [-1, 257, 128]               0
#       ResidualAdd-25             [-1, 257, 128]               0
#         LayerNorm-26             [-1, 257, 128]             256
#            Linear-27             [-1, 257, 512]          66,048
#              GELU-28             [-1, 257, 512]               0
#           Dropout-29             [-1, 257, 512]               0
#            Linear-30             [-1, 257, 128]          65,664
#           Dropout-31             [-1, 257, 128]               0
#       ResidualAdd-32             [-1, 257, 128]               0
#         LayerNorm-33             [-1, 257, 128]             256
#            Linear-34             [-1, 257, 384]          49,536
#           Dropout-35          [-1, 8, 257, 257]               0
#            Linear-36             [-1, 257, 128]          16,512
# MultiHeadAttention-37             [-1, 257, 128]               0
#           Dropout-38             [-1, 257, 128]               0
#       ResidualAdd-39             [-1, 257, 128]               0
#         LayerNorm-40             [-1, 257, 128]             256
#            Linear-41             [-1, 257, 512]          66,048
#              GELU-42             [-1, 257, 512]               0
#           Dropout-43             [-1, 257, 512]               0
#            Linear-44             [-1, 257, 128]          65,664
#           Dropout-45             [-1, 257, 128]               0
#       ResidualAdd-46             [-1, 257, 128]               0
#         LayerNorm-47             [-1, 257, 128]             256
#            Linear-48             [-1, 257, 384]          49,536
#           Dropout-49          [-1, 8, 257, 257]               0
#            Linear-50             [-1, 257, 128]          16,512
# MultiHeadAttention-51             [-1, 257, 128]               0
#           Dropout-52             [-1, 257, 128]               0
#       ResidualAdd-53             [-1, 257, 128]               0
#         LayerNorm-54             [-1, 257, 128]             256
#            Linear-55             [-1, 257, 512]          66,048
#              GELU-56             [-1, 257, 512]               0
#           Dropout-57             [-1, 257, 512]               0
#            Linear-58             [-1, 257, 128]          65,664
#           Dropout-59             [-1, 257, 128]               0
#       ResidualAdd-60             [-1, 257, 128]               0
#         LayerNorm-61             [-1, 257, 128]             256
#            Linear-62             [-1, 257, 384]          49,536
#           Dropout-63          [-1, 8, 257, 257]               0
#            Linear-64             [-1, 257, 128]          16,512
# MultiHeadAttention-65             [-1, 257, 128]               0
#           Dropout-66             [-1, 257, 128]               0
#       ResidualAdd-67             [-1, 257, 128]               0
#         LayerNorm-68             [-1, 257, 128]             256
#            Linear-69             [-1, 257, 512]          66,048
#              GELU-70             [-1, 257, 512]               0
#           Dropout-71             [-1, 257, 512]               0
#            Linear-72             [-1, 257, 128]          65,664
#           Dropout-73             [-1, 257, 128]               0
#       ResidualAdd-74             [-1, 257, 128]               0
#         LayerNorm-75             [-1, 257, 128]             256
#            Linear-76             [-1, 257, 384]          49,536
#           Dropout-77          [-1, 8, 257, 257]               0
#            Linear-78             [-1, 257, 128]          16,512
# MultiHeadAttention-79             [-1, 257, 128]               0
#           Dropout-80             [-1, 257, 128]               0
#       ResidualAdd-81             [-1, 257, 128]               0
#         LayerNorm-82             [-1, 257, 128]             256
#            Linear-83             [-1, 257, 512]          66,048
#              GELU-84             [-1, 257, 512]               0
#           Dropout-85             [-1, 257, 512]               0
#            Linear-86             [-1, 257, 128]          65,664
#           Dropout-87             [-1, 257, 128]               0
#       ResidualAdd-88             [-1, 257, 128]               0
#         LayerNorm-89             [-1, 257, 128]             256
#            Linear-90             [-1, 257, 384]          49,536
#           Dropout-91          [-1, 8, 257, 257]               0
#            Linear-92             [-1, 257, 128]          16,512
# MultiHeadAttention-93             [-1, 257, 128]               0
#           Dropout-94             [-1, 257, 128]               0
#       ResidualAdd-95             [-1, 257, 128]               0
#         LayerNorm-96             [-1, 257, 128]             256
#            Linear-97             [-1, 257, 512]          66,048
#              GELU-98             [-1, 257, 512]               0
#           Dropout-99             [-1, 257, 512]               0
#           Linear-100             [-1, 257, 128]          65,664
#          Dropout-101             [-1, 257, 128]               0
#      ResidualAdd-102             [-1, 257, 128]               0
#        LayerNorm-103             [-1, 257, 128]             256
#           Linear-104             [-1, 257, 384]          49,536
#          Dropout-105          [-1, 8, 257, 257]               0
#           Linear-106             [-1, 257, 128]          16,512
# MultiHeadAttention-107             [-1, 257, 128]               0
#          Dropout-108             [-1, 257, 128]               0
#      ResidualAdd-109             [-1, 257, 128]               0
#        LayerNorm-110             [-1, 257, 128]             256
#           Linear-111             [-1, 257, 512]          66,048
#             GELU-112             [-1, 257, 512]               0
#          Dropout-113             [-1, 257, 512]               0
#           Linear-114             [-1, 257, 128]          65,664
#          Dropout-115             [-1, 257, 128]               0
#      ResidualAdd-116             [-1, 257, 128]               0
#           Reduce-117                  [-1, 128]               0
#        LayerNorm-118                  [-1, 128]             256
#           Linear-119                    [-1, 2]             258
# ================================================================
# Total params: 2,656,990
# Trainable params: 2,656,990
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.95
# Forward/backward pass size (MB): 84.74
# Params size (MB): 10.14
# Estimated Total Size (MB): 95.82
# ----------------------------------------------------------------

# %% [markdown]
# # 데이터 학습

# %%
import os
import torch
import torchvision
import torch.nn as nn
from torch.utils.data import DataLoader, random_split, WeightedRandomSampler
from torchvision import datasets, transforms
import torch.optim as optim
from collections import Counter
from early import *  # 조기 종료 콜백

# 1. 데이터 전처리 정의
transform = transforms.Compose([
    transforms.Resize((288, 288), antialias=True),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

batch_size = 64
data_dir = './converted-dataset/train'  # class0/class1 포함

# 2. ImageFolder로 전체 데이터셋 로딩
dataset = datasets.ImageFolder(root=data_dir, transform=transform)
classes = dataset.classes
print(f"클래스: {classes}")  # 예: ['class0', 'class1']

# 3. 7:2:1 비율로 Split
total_size = len(dataset)
train_size = int(0.6 * total_size)
val_size = int(0.2 * total_size)
test_size = total_size - train_size - val_size

trainset, valset, testset = random_split(dataset, [train_size, val_size, test_size])
print(f"➡️ Train: {len(trainset)}, Val: {len(valset)}, Test: {len(testset)}")

# ✅ 4. WeightedRandomSampler: trainset만 대상
train_targets = [dataset.targets[i] for i in trainset.indices]
train_class_counts = Counter(train_targets)
print(f"Train Class Count: {train_class_counts}")

# 클래스 비율 기반 가중치 계산
class_weights = 1. / torch.tensor([train_class_counts[0], train_class_counts[1]], dtype=torch.float)
sample_weights = torch.tensor([class_weights[t] for t in train_targets])
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)

# ✅ 5. DataLoader 구성
trainloader = DataLoader(trainset, batch_size=batch_size, sampler=sampler, num_workers=2)
valloader = DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=2)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# 클래스: ['class0', 'class1']
# ➡️ Train: 240635, Val: 80211, Test: 80213
# Train Class Count: Counter({0: 240396, 1: 239})

# %%
from early import * batch_size

# ✅ 모델/손실/최적화 설정2
device = torch.device('cuda:0')
vit = ViT(in_channels=3, patch_size=18, emb_size=128, img_size=288, depth=8, n_classes=2).to(device)

epochs = 50
lr = 0.001
patience = 10
early_stopping = EarlyStopping(patience=patience, verbose=True)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(vit.parameters(), lr=lr, momentum=0.9)

os.makedirs('./pt', exist_ok=True)
best_val_loss = float('inf')



def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image, label = image.to(device), label.to(device).long()
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print(f"Train Epoch: {epoch}[{batch_idx*len(image)}/{len(train_loader.dataset)}({100*batch_idx/len(train_loader):.0f}%)]\t Train Loss : {loss.item():.6f}")

def evaluate(model, test_loader):
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for image, label in test_loader:
            image, label = image.to(device), label.to(device).long()
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1)[1]
            correct += prediction.eq(label).sum().item()

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
# ✅ 학습 루프
import torch

best_val_loss = float('inf')

try:
    for epoch in range(1, epochs + 1):
        train(vit, trainloader, optimizer, log_interval=5)
        val_loss, val_acc = evaluate(vit, valloader)
        print(f"\n[Epoch: {epoch}],\t Val Loss : {val_loss:.4f},\t Val Accuracy : {val_acc:.2f} %\n")

        # 🌟 val_loss가 개선되면 저장
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(vit.state_dict(), f'./pt/model_epoch_{epoch}_Accuracy_{val_acc:.2f}.pt')

        # 🌟 조기 종료 여부 확인
        early_stopping(val_loss, vit)
        if early_stopping.early_stop:
            print("Early stopping triggered.")
            break

except RuntimeError as e:
    if 'CUDA out of memory' in str(e):
        print("⚠️ CUDA OOM 발생! 모델을 자동 저장합니다.")
        torch.save(vit.state_dict(), "./pt/model_crashed_due_to_cuda_oom.pt")
    raise  # 에러 다시 발생시켜 로그 확인 가능하게 함
# Out:
# Train Epoch: 1[0/240635(0%)]	 Train Loss : 0.952246
# Train Epoch: 1[320/240635(0%)]	 Train Loss : 0.866816
# Train Epoch: 1[640/240635(0%)]	 Train Loss : 0.699663
# Train Epoch: 1[960/240635(0%)]	 Train Loss : 0.715252
# Train Epoch: 1[1280/240635(1%)]	 Train Loss : 0.781185
# Train Epoch: 1[1600/240635(1%)]	 Train Loss : 0.774803
# Train Epoch: 1[1920/240635(1%)]	 Train Loss : 0.697519
# Train Epoch: 1[2240/240635(1%)]	 Train Loss : 0.660249
# Train Epoch: 1[2560/240635(1%)]	 Train Loss : 0.654664
# Train Epoch: 1[2880/240635(1%)]	 Train Loss : 0.686725
# Train Epoch: 1[3200/240635(1%)]	 Train Loss : 0.636193
# Train Epoch: 1[3520/240635(1%)]	 Train Loss : 0.644318
# Train Epoch: 1[3840/240635(2%)]	 Train Loss : 0.650175
# Train Epoch: 1[4160/240635(2%)]	 Train Loss : 0.595808
# Train Epoch: 1[4480/240635(2%)]	 Train Loss : 0.632812
# Train Epoch: 1[4800/240635(2%)]	 Train Loss : 0.664425
# Train Epoch: 1[5120/240635(2%)]	 Train Loss : 0.660424
# Train Epoch: 1[5440/240635(2%)]	 Train Loss : 0.610837
# Train Epoch: 1[5760/240635(2%)]	 Train Loss : 0.650242
# Train Epoch: 1[6080/240635(3%)]	 Train Loss : 0.620992
# Train Epoch: 1[6400/240635(3%)]	 Train Loss : 0.668547
# Train Epoch: 1[6720/240635(3%)]	 Train Loss : 0.665214
# Train Epoch: 1[7040/240635(3%)]	 Train Loss : 0.683854
# Train Epoch: 1[7360/240635(3%)]	 Train Loss : 0.767988
# Train Epoch: 1[7680/240635(3%)]	 Train Loss : 0.642362
# Train Epoch: 1[8000/240635(3%)]	 Train Loss : 0.672707
# Train Epoch: 1[8320/240635(3%)]	 Train Loss : 0.615110
# Train Epoch: 1[8640/240635(4%)]	 Train Loss : 0.607647
# Train Epoch: 1[8960/240635(4%)]	 Train Loss : 0.705747
# Train Epoch: 1[9280/240635(4%)]	 Train Loss : 0.676053
# Train Epoch: 1[9600/240635(4%)]	 Train Loss : 0.628162
# Train Epoch: 1[9920/240635(4%)]	 Train Loss : 0.637276
# Train Epoch: 1[10240/240635(4%)]	 Train Loss : 0.732064
# Train Epoch: 1[10560/240635(4%)]	 Train Loss : 0.620026
# Train Epoch: 1[10880/240635(5%)]	 Train Loss : 0.658953
# Train Epoch: 1[11200/240635(5%)]	 Train Loss : 0.805448
# Train Epoch: 1[11520/240635(5%)]	 Train Loss : 0.700578
# Train Epoch: 1[11840/240635(5%)]	 Train Loss : 0.593115
# Train Epoch: 1[12160/240635(5%)]	 Train Loss : 0.669114
# Train Epoch: 1[12480/240635(5%)]	 Train Loss : 0.631566
# Train Epoch: 1[12800/240635(5%)]	 Train Loss : 0.633136
# Train Epoch: 1[13120/240635(5%)]	 Train Loss : 0.631545
# Train Epoch: 1[13440/240635(6%)]	 Train Loss : 0.673148
# Train Epoch: 1[13760/240635(6%)]	 Train Loss : 0.650228
# Train Epoch: 1[14080/240635(6%)]	 Train Loss : 0.669833
# Train Epoch: 1[14400/240635(6%)]	 Train Loss : 0.680441
# Train Epoch: 1[14720/240635(6%)]	 Train Loss : 0.664396
# Train Epoch: 1[15040/240635(6%)]	 Train Loss : 0.619574
# Train Epoch: 1[15360/240635(6%)]	 Train Loss : 0.652732
# Train Epoch: 1[15680/240635(7%)]	 Train Loss : 0.599956
# Train Epoch: 1[16000/240635(7%)]	 Train Loss : 0.627802
# Train Epoch: 1[16320/240635(7%)]	 Train Loss : 0.643294
# Train Epoch: 1[16640/240635(7%)]	 Train Loss : 0.627834
# Train Epoch: 1[16960/240635(7%)]	 Train Loss : 0.617530
# Train Epoch: 1[17280/240635(7%)]	 Train Loss : 0.693170
# Train Epoch: 1[17600/240635(7%)]	 Train Loss : 0.688344
# Train Epoch: 1[17920/240635(7%)]	 Train Loss : 0.647060
# Train Epoch: 1[18240/240635(8%)]	 Train Loss : 0.655700
# Train Epoch: 1[18560/240635(8%)]	 Train Loss : 0.663796
# Train Epoch: 1[18880/240635(8%)]	 Train Loss : 0.610069
# Train Epoch: 1[19200/240635(8%)]	 Train Loss : 0.638411
# Train Epoch: 1[19520/240635(8%)]	 Train Loss : 0.622254
# Train Epoch: 1[19840/240635(8%)]	 Train Loss : 0.668136
# Train Epoch: 1[20160/240635(8%)]	 Train Loss : 0.638142
# Train Epoch: 1[20480/240635(9%)]	 Train Loss : 0.587776
# Train Epoch: 1[20800/240635(9%)]	 Train Loss : 0.635738
# Train Epoch: 1[21120/240635(9%)]	 Train Loss : 0.607396
# Train Epoch: 1[21440/240635(9%)]	 Train Loss : 0.634246
# Train Epoch: 1[21760/240635(9%)]	 Train Loss : 0.661422
# Train Epoch: 1[22080/240635(9%)]	 Train Loss : 0.624584
# Train Epoch: 1[22400/240635(9%)]	 Train Loss : 0.532788
# Train Epoch: 1[22720/240635(9%)]	 Train Loss : 0.651656
# Train Epoch: 1[23040/240635(10%)]	 Train Loss : 0.644075
# Train Epoch: 1[23360/240635(10%)]	 Train Loss : 0.601090
# Train Epoch: 1[23680/240635(10%)]	 Train Loss : 0.588886
# Train Epoch: 1[24000/240635(10%)]	 Train Loss : 0.679736
# Train Epoch: 1[24320/240635(10%)]	 Train Loss : 0.657949
# Train Epoch: 1[24640/240635(10%)]	 Train Loss : 0.603785
# Train Epoch: 1[24960/240635(10%)]	 Train Loss : 0.656921
# Train Epoch: 1[25280/240635(11%)]	 Train Loss : 0.588323
# Train Epoch: 1[25600/240635(11%)]	 Train Loss : 0.617050
# Train Epoch: 1[25920/240635(11%)]	 Train Loss : 0.659745
# Train Epoch: 1[26240/240635(11%)]	 Train Loss : 0.659355
# Train Epoch: 1[26560/240635(11%)]	 Train Loss : 0.600616
# Train Epoch: 1[26880/240635(11%)]	 Train Loss : 0.610391
# Train Epoch: 1[27200/240635(11%)]	 Train Loss : 0.625705
# Train Epoch: 1[27520/240635(11%)]	 Train Loss : 0.612298
# Train Epoch: 1[27840/240635(12%)]	 Train Loss : 0.551814
# Train Epoch: 1[28160/240635(12%)]	 Train Loss : 0.691134
# Train Epoch: 1[28480/240635(12%)]	 Train Loss : 0.601404
# Train Epoch: 1[28800/240635(12%)]	 Train Loss : 0.667601
# Train Epoch: 1[29120/240635(12%)]	 Train Loss : 0.596359
# Train Epoch: 1[29440/240635(12%)]	 Train Loss : 0.598002
# Train Epoch: 1[29760/240635(12%)]	 Train Loss : 0.620747
# Train Epoch: 1[30080/240635(12%)]	 Train Loss : 0.659070
# Train Epoch: 1[30400/240635(13%)]	 Train Loss : 0.570482
# Train Epoch: 1[30720/240635(13%)]	 Train Loss : 0.552684
# Train Epoch: 1[31040/240635(13%)]	 Train Loss : 0.656828
# Train Epoch: 1[31360/240635(13%)]	 Train Loss : 0.580298
# Train Epoch: 1[31680/240635(13%)]	 Train Loss : 0.570658
# Train Epoch: 1[32000/240635(13%)]	 Train Loss : 0.622423
# Train Epoch: 1[32320/240635(13%)]	 Train Loss : 0.578188
# Train Epoch: 1[32640/240635(14%)]	 Train Loss : 0.618698
# Train Epoch: 1[32960/240635(14%)]	 Train Loss : 0.601045
# Train Epoch: 1[33280/240635(14%)]	 Train Loss : 0.642064
# Train Epoch: 1[33600/240635(14%)]	 Train Loss : 0.540442
# Train Epoch: 1[33920/240635(14%)]	 Train Loss : 0.601025
# Train Epoch: 1[34240/240635(14%)]	 Train Loss : 0.598935
# Train Epoch: 1[34560/240635(14%)]	 Train Loss : 0.681621
# Train Epoch: 1[34880/240635(14%)]	 Train Loss : 0.553003
# Train Epoch: 1[35200/240635(15%)]	 Train Loss : 0.637723
# Train Epoch: 1[35520/240635(15%)]	 Train Loss : 0.671505
# Train Epoch: 1[35840/240635(15%)]	 Train Loss : 0.598785
# Train Epoch: 1[36160/240635(15%)]	 Train Loss : 0.621991
# Train Epoch: 1[36480/240635(15%)]	 Train Loss : 0.604406
# Train Epoch: 1[36800/240635(15%)]	 Train Loss : 0.596269
# Train Epoch: 1[37120/240635(15%)]	 Train Loss : 0.705370
# Train Epoch: 1[37440/240635(16%)]	 Train Loss : 0.786374
# Train Epoch: 1[37760/240635(16%)]	 Train Loss : 0.566489
# Train Epoch: 1[38080/240635(16%)]	 Train Loss : 0.556960
# Train Epoch: 1[38400/240635(16%)]	 Train Loss : 0.601740
# Train Epoch: 1[38720/240635(16%)]	 Train Loss : 0.690755
# Train Epoch: 1[39040/240635(16%)]	 Train Loss : 0.673653
# Train Epoch: 1[39360/240635(16%)]	 Train Loss : 0.561722
# Train Epoch: 1[39680/240635(16%)]	 Train Loss : 0.628330
# Train Epoch: 1[40000/240635(17%)]	 Train Loss : 0.565320
# Train Epoch: 1[40320/240635(17%)]	 Train Loss : 0.645994
# Train Epoch: 1[40640/240635(17%)]	 Train Loss : 0.664573
# Train Epoch: 1[40960/240635(17%)]	 Train Loss : 0.612322
# Train Epoch: 1[41280/240635(17%)]	 Train Loss : 0.622644
# Train Epoch: 1[41600/240635(17%)]	 Train Loss : 0.609757
# Train Epoch: 1[41920/240635(17%)]	 Train Loss : 0.624934
# Train Epoch: 1[42240/240635(18%)]	 Train Loss : 0.628288
# Train Epoch: 1[42560/240635(18%)]	 Train Loss : 0.649259
# Train Epoch: 1[42880/240635(18%)]	 Train Loss : 0.631504
# Train Epoch: 1[43200/240635(18%)]	 Train Loss : 0.551172
# Train Epoch: 1[43520/240635(18%)]	 Train Loss : 0.653696
# Train Epoch: 1[43840/240635(18%)]	 Train Loss : 0.593302
# Train Epoch: 1[44160/240635(18%)]	 Train Loss : 0.600954
# Train Epoch: 1[44480/240635(18%)]	 Train Loss : 0.657094
# Train Epoch: 1[44800/240635(19%)]	 Train Loss : 0.616609
# Train Epoch: 1[45120/240635(19%)]	 Train Loss : 0.586997
# Train Epoch: 1[45440/240635(19%)]	 Train Loss : 0.615766
# Train Epoch: 1[45760/240635(19%)]	 Train Loss : 0.632437
# Train Epoch: 1[46080/240635(19%)]	 Train Loss : 0.597026
# Train Epoch: 1[46400/240635(19%)]	 Train Loss : 0.597242
# Train Epoch: 1[46720/240635(19%)]	 Train Loss : 0.734889
# Train Epoch: 1[47040/240635(20%)]	 Train Loss : 0.563835
# Train Epoch: 1[47360/240635(20%)]	 Train Loss : 0.784126
# Train Epoch: 1[47680/240635(20%)]	 Train Loss : 0.645973
# Train Epoch: 1[48000/240635(20%)]	 Train Loss : 0.639163
# Train Epoch: 1[48320/240635(20%)]	 Train Loss : 0.608956
# Train Epoch: 1[48640/240635(20%)]	 Train Loss : 0.588063
# Train Epoch: 1[48960/240635(20%)]	 Train Loss : 0.630792
# Train Epoch: 1[49280/240635(20%)]	 Train Loss : 0.633176
# Train Epoch: 1[49600/240635(21%)]	 Train Loss : 0.658754
# Train Epoch: 1[49920/240635(21%)]	 Train Loss : 0.637878
# Train Epoch: 1[50240/240635(21%)]	 Train Loss : 0.583573
# Train Epoch: 1[50560/240635(21%)]	 Train Loss : 0.634160
# Train Epoch: 1[50880/240635(21%)]	 Train Loss : 0.687918
# Train Epoch: 1[51200/240635(21%)]	 Train Loss : 0.612898
# Train Epoch: 1[51520/240635(21%)]	 Train Loss : 0.623375
# Train Epoch: 1[51840/240635(22%)]	 Train Loss : 0.584253
# Train Epoch: 1[52160/240635(22%)]	 Train Loss : 0.669038
# Train Epoch: 1[52480/240635(22%)]	 Train Loss : 0.672792
# Train Epoch: 1[52800/240635(22%)]	 Train Loss : 0.613186
# Train Epoch: 1[53120/240635(22%)]	 Train Loss : 0.645796
# Train Epoch: 1[53440/240635(22%)]	 Train Loss : 0.631745
# Train Epoch: 1[53760/240635(22%)]	 Train Loss : 0.750077
# Train Epoch: 1[54080/240635(22%)]	 Train Loss : 0.651713
# Train Epoch: 1[54400/240635(23%)]	 Train Loss : 0.695452
# Train Epoch: 1[54720/240635(23%)]	 Train Loss : 0.603874
# Train Epoch: 1[55040/240635(23%)]	 Train Loss : 0.587411
# Train Epoch: 1[55360/240635(23%)]	 Train Loss : 0.658847
# Train Epoch: 1[55680/240635(23%)]	 Train Loss : 0.563103
# Train Epoch: 1[56000/240635(23%)]	 Train Loss : 0.672993
# Train Epoch: 1[56320/240635(23%)]	 Train Loss : 0.618123
# Train Epoch: 1[56640/240635(24%)]	 Train Loss : 0.671366
# Train Epoch: 1[56960/240635(24%)]	 Train Loss : 0.566825
# Train Epoch: 1[57280/240635(24%)]	 Train Loss : 0.654859
# Train Epoch: 1[57600/240635(24%)]	 Train Loss : 0.664864
# Train Epoch: 1[57920/240635(24%)]	 Train Loss : 0.591749
# Train Epoch: 1[58240/240635(24%)]	 Train Loss : 0.677111
# Train Epoch: 1[58560/240635(24%)]	 Train Loss : 0.600355
# Train Epoch: 1[58880/240635(24%)]	 Train Loss : 0.623897
# Train Epoch: 1[59200/240635(25%)]	 Train Loss : 0.650203
# Train Epoch: 1[59520/240635(25%)]	 Train Loss : 0.619088
# Train Epoch: 1[59840/240635(25%)]	 Train Loss : 0.583688
# Train Epoch: 1[60160/240635(25%)]	 Train Loss : 0.646992
# Train Epoch: 1[60480/240635(25%)]	 Train Loss : 0.592172
# Train Epoch: 1[60800/240635(25%)]	 Train Loss : 0.727202
# Train Epoch: 1[61120/240635(25%)]	 Train Loss : 0.662853
# Train Epoch: 1[61440/240635(26%)]	 Train Loss : 0.610371
# Train Epoch: 1[61760/240635(26%)]	 Train Loss : 0.599573
# Train Epoch: 1[62080/240635(26%)]	 Train Loss : 0.565358
# Train Epoch: 1[62400/240635(26%)]	 Train Loss : 0.697935
# Train Epoch: 1[62720/240635(26%)]	 Train Loss : 0.693674
# Train Epoch: 1[63040/240635(26%)]	 Train Loss : 0.633370
# Train Epoch: 1[63360/240635(26%)]	 Train Loss : 0.628262
# Train Epoch: 1[63680/240635(26%)]	 Train Loss : 0.585582
# Train Epoch: 1[64000/240635(27%)]	 Train Loss : 0.543207
# Train Epoch: 1[64320/240635(27%)]	 Train Loss : 0.658037
# Train Epoch: 1[64640/240635(27%)]	 Train Loss : 0.562629
# Train Epoch: 1[64960/240635(27%)]	 Train Loss : 0.648083
# Train Epoch: 1[65280/240635(27%)]	 Train Loss : 0.590586
# Train Epoch: 1[65600/240635(27%)]	 Train Loss : 0.602878
# Train Epoch: 1[65920/240635(27%)]	 Train Loss : 0.640595
# Train Epoch: 1[66240/240635(28%)]	 Train Loss : 0.610185
# Train Epoch: 1[66560/240635(28%)]	 Train Loss : 0.603856
# Train Epoch: 1[66880/240635(28%)]	 Train Loss : 0.628022
# Train Epoch: 1[67200/240635(28%)]	 Train Loss : 0.678171
# Train Epoch: 1[67520/240635(28%)]	 Train Loss : 0.664792
# Train Epoch: 1[67840/240635(28%)]	 Train Loss : 0.579143
# Train Epoch: 1[68160/240635(28%)]	 Train Loss : 0.617022
# Train Epoch: 1[68480/240635(28%)]	 Train Loss : 0.568383
# Train Epoch: 1[68800/240635(29%)]	 Train Loss : 0.597600
# Train Epoch: 1[69120/240635(29%)]	 Train Loss : 0.597782
# Train Epoch: 1[69440/240635(29%)]	 Train Loss : 0.619151
# Train Epoch: 1[69760/240635(29%)]	 Train Loss : 0.580091
# Train Epoch: 1[70080/240635(29%)]	 Train Loss : 0.639770
# Train Epoch: 1[70400/240635(29%)]	 Train Loss : 0.549186
# Train Epoch: 1[70720/240635(29%)]	 Train Loss : 0.661047
# Train Epoch: 1[71040/240635(30%)]	 Train Loss : 0.642576
# Train Epoch: 1[71360/240635(30%)]	 Train Loss : 0.580176
# Train Epoch: 1[71680/240635(30%)]	 Train Loss : 0.634424
# Train Epoch: 1[72000/240635(30%)]	 Train Loss : 0.593234
# Train Epoch: 1[72320/240635(30%)]	 Train Loss : 0.691942
# Train Epoch: 1[72640/240635(30%)]	 Train Loss : 0.570454
# Train Epoch: 1[72960/240635(30%)]	 Train Loss : 0.648887
# Train Epoch: 1[73280/240635(30%)]	 Train Loss : 0.581267
# Train Epoch: 1[73600/240635(31%)]	 Train Loss : 0.623695
# Train Epoch: 1[73920/240635(31%)]	 Train Loss : 0.658819
# Train Epoch: 1[74240/240635(31%)]	 Train Loss : 0.583593
# Train Epoch: 1[74560/240635(31%)]	 Train Loss : 0.585831
# Train Epoch: 1[74880/240635(31%)]	 Train Loss : 0.673710
# Train Epoch: 1[75200/240635(31%)]	 Train Loss : 0.655548
# Train Epoch: 1[75520/240635(31%)]	 Train Loss : 0.575905
# Train Epoch: 1[75840/240635(32%)]	 Train Loss : 0.696309
# Train Epoch: 1[76160/240635(32%)]	 Train Loss : 0.596580
# Train Epoch: 1[76480/240635(32%)]	 Train Loss : 0.671115
# Train Epoch: 1[76800/240635(32%)]	 Train Loss : 0.564659
# Train Epoch: 1[77120/240635(32%)]	 Train Loss : 0.638705
# Train Epoch: 1[77440/240635(32%)]	 Train Loss : 0.620523
# Train Epoch: 1[77760/240635(32%)]	 Train Loss : 0.692734
# Train Epoch: 1[78080/240635(32%)]	 Train Loss : 0.592374
# Train Epoch: 1[78400/240635(33%)]	 Train Loss : 0.657188
# Train Epoch: 1[78720/240635(33%)]	 Train Loss : 0.565006
# Train Epoch: 1[79040/240635(33%)]	 Train Loss : 0.700473
# Train Epoch: 1[79360/240635(33%)]	 Train Loss : 0.613760
# Train Epoch: 1[79680/240635(33%)]	 Train Loss : 0.616457
# Train Epoch: 1[80000/240635(33%)]	 Train Loss : 0.627033
# Train Epoch: 1[80320/240635(33%)]	 Train Loss : 0.725845
# Train Epoch: 1[80640/240635(34%)]	 Train Loss : 0.644049
# Train Epoch: 1[80960/240635(34%)]	 Train Loss : 0.650388
# Train Epoch: 1[81280/240635(34%)]	 Train Loss : 0.629779
# Train Epoch: 1[81600/240635(34%)]	 Train Loss : 0.623897
# Train Epoch: 1[81920/240635(34%)]	 Train Loss : 0.630142
# Train Epoch: 1[82240/240635(34%)]	 Train Loss : 0.619359
# Train Epoch: 1[82560/240635(34%)]	 Train Loss : 0.616035
# Train Epoch: 1[82880/240635(34%)]	 Train Loss : 0.660887
# Train Epoch: 1[83200/240635(35%)]	 Train Loss : 0.681825
# Train Epoch: 1[83520/240635(35%)]	 Train Loss : 0.540321
# Train Epoch: 1[83840/240635(35%)]	 Train Loss : 0.647170
# Train Epoch: 1[84160/240635(35%)]	 Train Loss : 0.544225
# Train Epoch: 1[84480/240635(35%)]	 Train Loss : 0.638966
# Train Epoch: 1[84800/240635(35%)]	 Train Loss : 0.625233
# Train Epoch: 1[85120/240635(35%)]	 Train Loss : 0.636702
# Train Epoch: 1[85440/240635(36%)]	 Train Loss : 0.655787
# Train Epoch: 1[85760/240635(36%)]	 Train Loss : 0.583316
# Train Epoch: 1[86080/240635(36%)]	 Train Loss : 0.685606
# Train Epoch: 1[86400/240635(36%)]	 Train Loss : 0.695943
# Train Epoch: 1[86720/240635(36%)]	 Train Loss : 0.597486
# Train Epoch: 1[87040/240635(36%)]	 Train Loss : 0.606535
# Train Epoch: 1[87360/240635(36%)]	 Train Loss : 0.580485
# Train Epoch: 1[87680/240635(36%)]	 Train Loss : 0.595754
# Train Epoch: 1[88000/240635(37%)]	 Train Loss : 0.701152
# Train Epoch: 1[88320/240635(37%)]	 Train Loss : 0.560395
# Train Epoch: 1[88640/240635(37%)]	 Train Loss : 0.555127
# Train Epoch: 1[88960/240635(37%)]	 Train Loss : 0.674854
# Train Epoch: 1[89280/240635(37%)]	 Train Loss : 0.611464
# Train Epoch: 1[89600/240635(37%)]	 Train Loss : 0.641793
# Train Epoch: 1[89920/240635(37%)]	 Train Loss : 0.672597
# Train Epoch: 1[90240/240635(38%)]	 Train Loss : 0.641814
# Train Epoch: 1[90560/240635(38%)]	 Train Loss : 0.693559
# Train Epoch: 1[90880/240635(38%)]	 Train Loss : 0.642949
# Train Epoch: 1[91200/240635(38%)]	 Train Loss : 0.621772
# Train Epoch: 1[91520/240635(38%)]	 Train Loss : 0.576993
# Train Epoch: 1[91840/240635(38%)]	 Train Loss : 0.618985
# Train Epoch: 1[92160/240635(38%)]	 Train Loss : 0.544384
# Train Epoch: 1[92480/240635(38%)]	 Train Loss : 0.596347
# Train Epoch: 1[92800/240635(39%)]	 Train Loss : 0.598263
# Train Epoch: 1[93120/240635(39%)]	 Train Loss : 0.635825
# Train Epoch: 1[93440/240635(39%)]	 Train Loss : 0.615145
# Train Epoch: 1[93760/240635(39%)]	 Train Loss : 0.657783
# Train Epoch: 1[94080/240635(39%)]	 Train Loss : 0.687344
# Train Epoch: 1[94400/240635(39%)]	 Train Loss : 0.657531
# Train Epoch: 1[94720/240635(39%)]	 Train Loss : 0.590124
# Train Epoch: 1[95040/240635(39%)]	 Train Loss : 0.616574
# Train Epoch: 1[95360/240635(40%)]	 Train Loss : 0.644233
# Train Epoch: 1[95680/240635(40%)]	 Train Loss : 0.586392
# Train Epoch: 1[96000/240635(40%)]	 Train Loss : 0.625465
# Train Epoch: 1[96320/240635(40%)]	 Train Loss : 0.563325
# Train Epoch: 1[96640/240635(40%)]	 Train Loss : 0.622068
# Train Epoch: 1[96960/240635(40%)]	 Train Loss : 0.616404
# Train Epoch: 1[97280/240635(40%)]	 Train Loss : 0.723186
# Train Epoch: 1[97600/240635(41%)]	 Train Loss : 0.627963
# Train Epoch: 1[97920/240635(41%)]	 Train Loss : 0.583430
# Train Epoch: 1[98240/240635(41%)]	 Train Loss : 0.625643
# Train Epoch: 1[98560/240635(41%)]	 Train Loss : 0.624158
# Train Epoch: 1[98880/240635(41%)]	 Train Loss : 0.632579
# Train Epoch: 1[99200/240635(41%)]	 Train Loss : 0.546387
# Train Epoch: 1[99520/240635(41%)]	 Train Loss : 0.720179
# Train Epoch: 1[99840/240635(41%)]	 Train Loss : 0.584310
# Train Epoch: 1[100160/240635(42%)]	 Train Loss : 0.673378
# Train Epoch: 1[100480/240635(42%)]	 Train Loss : 0.713900
# Train Epoch: 1[100800/240635(42%)]	 Train Loss : 0.564853
# Train Epoch: 1[101120/240635(42%)]	 Train Loss : 0.583389
# Train Epoch: 1[101440/240635(42%)]	 Train Loss : 0.634693
# Train Epoch: 1[101760/240635(42%)]	 Train Loss : 0.657709
# Train Epoch: 1[102080/240635(42%)]	 Train Loss : 0.629810
# Train Epoch: 1[102400/240635(43%)]	 Train Loss : 0.635561
# Train Epoch: 1[102720/240635(43%)]	 Train Loss : 0.610939
# Train Epoch: 1[103040/240635(43%)]	 Train Loss : 0.621934
# Train Epoch: 1[103360/240635(43%)]	 Train Loss : 0.650934
# Train Epoch: 1[103680/240635(43%)]	 Train Loss : 0.688093
# Train Epoch: 1[104000/240635(43%)]	 Train Loss : 0.648516
# Train Epoch: 1[104320/240635(43%)]	 Train Loss : 0.612557
# Train Epoch: 1[104640/240635(43%)]	 Train Loss : 0.584040
# Train Epoch: 1[104960/240635(44%)]	 Train Loss : 0.581853
# Train Epoch: 1[105280/240635(44%)]	 Train Loss : 0.679574
# Train Epoch: 1[105600/240635(44%)]	 Train Loss : 0.584084
# Train Epoch: 1[105920/240635(44%)]	 Train Loss : 0.566032
# Train Epoch: 1[106240/240635(44%)]	 Train Loss : 0.713245
# Train Epoch: 1[106560/240635(44%)]	 Train Loss : 0.541686
# Train Epoch: 1[106880/240635(44%)]	 Train Loss : 0.661491
# Train Epoch: 1[107200/240635(45%)]	 Train Loss : 0.627630
# Train Epoch: 1[107520/240635(45%)]	 Train Loss : 0.564684
# Train Epoch: 1[107840/240635(45%)]	 Train Loss : 0.648489
# Train Epoch: 1[108160/240635(45%)]	 Train Loss : 0.633119
# Train Epoch: 1[108480/240635(45%)]	 Train Loss : 0.726971
# Train Epoch: 1[108800/240635(45%)]	 Train Loss : 0.644326
# Train Epoch: 1[109120/240635(45%)]	 Train Loss : 0.565235
# Train Epoch: 1[109440/240635(45%)]	 Train Loss : 0.560579
# Train Epoch: 1[109760/240635(46%)]	 Train Loss : 0.670914
# Train Epoch: 1[110080/240635(46%)]	 Train Loss : 0.565276
# Train Epoch: 1[110400/240635(46%)]	 Train Loss : 0.523072
# Train Epoch: 1[110720/240635(46%)]	 Train Loss : 0.667189
# Train Epoch: 1[111040/240635(46%)]	 Train Loss : 0.607118
# Train Epoch: 1[111360/240635(46%)]	 Train Loss : 0.626325
# Train Epoch: 1[111680/240635(46%)]	 Train Loss : 0.648924
# Train Epoch: 1[112000/240635(47%)]	 Train Loss : 0.552220
# Train Epoch: 1[112320/240635(47%)]	 Train Loss : 0.629705
# Train Epoch: 1[112640/240635(47%)]	 Train Loss : 0.703767
# Train Epoch: 1[112960/240635(47%)]	 Train Loss : 0.608223
# Train Epoch: 1[113280/240635(47%)]	 Train Loss : 0.597565
# Train Epoch: 1[113600/240635(47%)]	 Train Loss : 0.605862
# Train Epoch: 1[113920/240635(47%)]	 Train Loss : 0.594869
# Train Epoch: 1[114240/240635(47%)]	 Train Loss : 0.635745
# Train Epoch: 1[114560/240635(48%)]	 Train Loss : 0.592666
# Train Epoch: 1[114880/240635(48%)]	 Train Loss : 0.658944
# Train Epoch: 1[115200/240635(48%)]	 Train Loss : 0.647911
# Train Epoch: 1[115520/240635(48%)]	 Train Loss : 0.620152
# Train Epoch: 1[115840/240635(48%)]	 Train Loss : 0.569189
# Train Epoch: 1[116160/240635(48%)]	 Train Loss : 0.663138
# Train Epoch: 1[116480/240635(48%)]	 Train Loss : 0.666215
# Train Epoch: 1[116800/240635(49%)]	 Train Loss : 0.653548
# Train Epoch: 1[117120/240635(49%)]	 Train Loss : 0.617312
# Train Epoch: 1[117440/240635(49%)]	 Train Loss : 0.594893
# Train Epoch: 1[117760/240635(49%)]	 Train Loss : 0.648758
# Train Epoch: 1[118080/240635(49%)]	 Train Loss : 0.676887
# Train Epoch: 1[118400/240635(49%)]	 Train Loss : 0.612584
# Train Epoch: 1[118720/240635(49%)]	 Train Loss : 0.575003
# Train Epoch: 1[119040/240635(49%)]	 Train Loss : 0.694104
# Train Epoch: 1[119360/240635(50%)]	 Train Loss : 0.598146
# Train Epoch: 1[119680/240635(50%)]	 Train Loss : 0.627825
# Train Epoch: 1[120000/240635(50%)]	 Train Loss : 0.539738
# Train Epoch: 1[120320/240635(50%)]	 Train Loss : 0.669352
# Train Epoch: 1[120640/240635(50%)]	 Train Loss : 0.549361
# Train Epoch: 1[120960/240635(50%)]	 Train Loss : 0.607624
# Train Epoch: 1[121280/240635(50%)]	 Train Loss : 0.545364
# Train Epoch: 1[121600/240635(51%)]	 Train Loss : 0.620415
# Train Epoch: 1[121920/240635(51%)]	 Train Loss : 0.626956
# Train Epoch: 1[122240/240635(51%)]	 Train Loss : 0.565004
# Train Epoch: 1[122560/240635(51%)]	 Train Loss : 0.688694
# Train Epoch: 1[122880/240635(51%)]	 Train Loss : 0.605240
# Train Epoch: 1[123200/240635(51%)]	 Train Loss : 0.579406
# Train Epoch: 1[123520/240635(51%)]	 Train Loss : 0.651906
# Train Epoch: 1[123840/240635(51%)]	 Train Loss : 0.587294
# Train Epoch: 1[124160/240635(52%)]	 Train Loss : 0.578133
# Train Epoch: 1[124480/240635(52%)]	 Train Loss : 0.595488
# Train Epoch: 1[124800/240635(52%)]	 Train Loss : 0.576370
# Train Epoch: 1[125120/240635(52%)]	 Train Loss : 0.559209
# Train Epoch: 1[125440/240635(52%)]	 Train Loss : 0.634255
# Train Epoch: 1[125760/240635(52%)]	 Train Loss : 0.615485
# Train Epoch: 1[126080/240635(52%)]	 Train Loss : 0.682939
# Train Epoch: 1[126400/240635(53%)]	 Train Loss : 0.645254
# Train Epoch: 1[126720/240635(53%)]	 Train Loss : 0.595159
# Train Epoch: 1[127040/240635(53%)]	 Train Loss : 0.547868
# Train Epoch: 1[127360/240635(53%)]	 Train Loss : 0.549514
# Train Epoch: 1[127680/240635(53%)]	 Train Loss : 0.576910
# Train Epoch: 1[128000/240635(53%)]	 Train Loss : 0.648431
# Train Epoch: 1[128320/240635(53%)]	 Train Loss : 0.600106
# Train Epoch: 1[128640/240635(53%)]	 Train Loss : 0.573914
# Train Epoch: 1[128960/240635(54%)]	 Train Loss : 0.609058
# Train Epoch: 1[129280/240635(54%)]	 Train Loss : 0.676752
# Train Epoch: 1[129600/240635(54%)]	 Train Loss : 0.594366
# Train Epoch: 1[129920/240635(54%)]	 Train Loss : 0.567934
# Train Epoch: 1[130240/240635(54%)]	 Train Loss : 0.657765
# Train Epoch: 1[130560/240635(54%)]	 Train Loss : 0.677787
# Train Epoch: 1[130880/240635(54%)]	 Train Loss : 0.594140
# Train Epoch: 1[131200/240635(55%)]	 Train Loss : 0.551791
# Train Epoch: 1[131520/240635(55%)]	 Train Loss : 0.631924
# Train Epoch: 1[131840/240635(55%)]	 Train Loss : 0.636193
# Train Epoch: 1[132160/240635(55%)]	 Train Loss : 0.599523
# Train Epoch: 1[132480/240635(55%)]	 Train Loss : 0.683277
# Train Epoch: 1[132800/240635(55%)]	 Train Loss : 0.649124
# Train Epoch: 1[133120/240635(55%)]	 Train Loss : 0.622272
# Train Epoch: 1[133440/240635(55%)]	 Train Loss : 0.616541
# Train Epoch: 1[133760/240635(56%)]	 Train Loss : 0.625895
# Train Epoch: 1[134080/240635(56%)]	 Train Loss : 0.619630
# Train Epoch: 1[134400/240635(56%)]	 Train Loss : 0.617758
# Train Epoch: 1[134720/240635(56%)]	 Train Loss : 0.653741
# Train Epoch: 1[135040/240635(56%)]	 Train Loss : 0.652650
# Train Epoch: 1[135360/240635(56%)]	 Train Loss : 0.581022
# Train Epoch: 1[135680/240635(56%)]	 Train Loss : 0.609480
# Train Epoch: 1[136000/240635(57%)]	 Train Loss : 0.639279
# Train Epoch: 1[136320/240635(57%)]	 Train Loss : 0.618198
# Train Epoch: 1[136640/240635(57%)]	 Train Loss : 0.649536
# Train Epoch: 1[136960/240635(57%)]	 Train Loss : 0.677994
# Train Epoch: 1[137280/240635(57%)]	 Train Loss : 0.647827
# Train Epoch: 1[137600/240635(57%)]	 Train Loss : 0.612476
# Train Epoch: 1[137920/240635(57%)]	 Train Loss : 0.631610
# Train Epoch: 1[138240/240635(57%)]	 Train Loss : 0.626606
# Train Epoch: 1[138560/240635(58%)]	 Train Loss : 0.721721
# Train Epoch: 1[138880/240635(58%)]	 Train Loss : 0.666620
# Train Epoch: 1[139200/240635(58%)]	 Train Loss : 0.667696
# Train Epoch: 1[139520/240635(58%)]	 Train Loss : 0.558975
# Train Epoch: 1[139840/240635(58%)]	 Train Loss : 0.580159
# Train Epoch: 1[140160/240635(58%)]	 Train Loss : 0.622207
# Train Epoch: 1[140480/240635(58%)]	 Train Loss : 0.602067
# Train Epoch: 1[140800/240635(59%)]	 Train Loss : 0.600626
# Train Epoch: 1[141120/240635(59%)]	 Train Loss : 0.568025
# Train Epoch: 1[141440/240635(59%)]	 Train Loss : 0.623996
# Train Epoch: 1[141760/240635(59%)]	 Train Loss : 0.594317
# Train Epoch: 1[142080/240635(59%)]	 Train Loss : 0.619125
# Train Epoch: 1[142400/240635(59%)]	 Train Loss : 0.578744
# Train Epoch: 1[142720/240635(59%)]	 Train Loss : 0.709362
# Train Epoch: 1[143040/240635(59%)]	 Train Loss : 0.621906
# Train Epoch: 1[143360/240635(60%)]	 Train Loss : 0.700391
# Train Epoch: 1[143680/240635(60%)]	 Train Loss : 0.676516
# Train Epoch: 1[144000/240635(60%)]	 Train Loss : 0.600753
# Train Epoch: 1[144320/240635(60%)]	 Train Loss : 0.648449
# Train Epoch: 1[144640/240635(60%)]	 Train Loss : 0.687772
# Train Epoch: 1[144960/240635(60%)]	 Train Loss : 0.620308
# Train Epoch: 1[145280/240635(60%)]	 Train Loss : 0.579397
# Train Epoch: 1[145600/240635(61%)]	 Train Loss : 0.582944
# Train Epoch: 1[145920/240635(61%)]	 Train Loss : 0.564588
# Train Epoch: 1[146240/240635(61%)]	 Train Loss : 0.716761
# Train Epoch: 1[146560/240635(61%)]	 Train Loss : 0.597404
# Train Epoch: 1[146880/240635(61%)]	 Train Loss : 0.609993
# Train Epoch: 1[147200/240635(61%)]	 Train Loss : 0.637777
# Train Epoch: 1[147520/240635(61%)]	 Train Loss : 0.620971
# Train Epoch: 1[147840/240635(61%)]	 Train Loss : 0.621555
# Train Epoch: 1[148160/240635(62%)]	 Train Loss : 0.621553
# Train Epoch: 1[148480/240635(62%)]	 Train Loss : 0.619488
# Train Epoch: 1[148800/240635(62%)]	 Train Loss : 0.671310
# Train Epoch: 1[149120/240635(62%)]	 Train Loss : 0.648736
# Train Epoch: 1[149440/240635(62%)]	 Train Loss : 0.596435
# Train Epoch: 1[149760/240635(62%)]	 Train Loss : 0.693984
# Train Epoch: 1[150080/240635(62%)]	 Train Loss : 0.580425
# Train Epoch: 1[150400/240635(62%)]	 Train Loss : 0.688249
# Train Epoch: 1[150720/240635(63%)]	 Train Loss : 0.631372
# Train Epoch: 1[151040/240635(63%)]	 Train Loss : 0.607119
# Train Epoch: 1[151360/240635(63%)]	 Train Loss : 0.708725
# Train Epoch: 1[151680/240635(63%)]	 Train Loss : 0.618582
# Train Epoch: 1[152000/240635(63%)]	 Train Loss : 0.552705
# Train Epoch: 1[152320/240635(63%)]	 Train Loss : 0.616037
# Train Epoch: 1[152640/240635(63%)]	 Train Loss : 0.568863
# Train Epoch: 1[152960/240635(64%)]	 Train Loss : 0.639127
# Train Epoch: 1[153280/240635(64%)]	 Train Loss : 0.528568
# Train Epoch: 1[153600/240635(64%)]	 Train Loss : 0.607309
# Train Epoch: 1[153920/240635(64%)]	 Train Loss : 0.644965
# Train Epoch: 1[154240/240635(64%)]	 Train Loss : 0.627343
# Train Epoch: 1[154560/240635(64%)]	 Train Loss : 0.532284
# Train Epoch: 1[154880/240635(64%)]	 Train Loss : 0.650750
# Train Epoch: 1[155200/240635(64%)]	 Train Loss : 0.661701
# Train Epoch: 1[155520/240635(65%)]	 Train Loss : 0.713743
# Train Epoch: 1[155840/240635(65%)]	 Train Loss : 0.548569
# Train Epoch: 1[156160/240635(65%)]	 Train Loss : 0.617725
# Train Epoch: 1[156480/240635(65%)]	 Train Loss : 0.637462
# Train Epoch: 1[156800/240635(65%)]	 Train Loss : 0.609702
# Train Epoch: 1[157120/240635(65%)]	 Train Loss : 0.637201
# Train Epoch: 1[157440/240635(65%)]	 Train Loss : 0.529781
# Train Epoch: 1[157760/240635(66%)]	 Train Loss : 0.634885
# Train Epoch: 1[158080/240635(66%)]	 Train Loss : 0.563628
# Train Epoch: 1[158400/240635(66%)]	 Train Loss : 0.636281
# Train Epoch: 1[158720/240635(66%)]	 Train Loss : 0.612299
# Train Epoch: 1[159040/240635(66%)]	 Train Loss : 0.681799
# Train Epoch: 1[159360/240635(66%)]	 Train Loss : 0.714152
# Train Epoch: 1[159680/240635(66%)]	 Train Loss : 0.630844
# Train Epoch: 1[160000/240635(66%)]	 Train Loss : 0.646977
# Train Epoch: 1[160320/240635(67%)]	 Train Loss : 0.614682
# Train Epoch: 1[160640/240635(67%)]	 Train Loss : 0.625088
# Train Epoch: 1[160960/240635(67%)]	 Train Loss : 0.641596
# Train Epoch: 1[161280/240635(67%)]	 Train Loss : 0.573727
# Train Epoch: 1[161600/240635(67%)]	 Train Loss : 0.634222
# Train Epoch: 1[161920/240635(67%)]	 Train Loss : 0.654155
# Train Epoch: 1[162240/240635(67%)]	 Train Loss : 0.531473
# Train Epoch: 1[162560/240635(68%)]	 Train Loss : 0.597495
# Train Epoch: 1[162880/240635(68%)]	 Train Loss : 0.588289
# Train Epoch: 1[163200/240635(68%)]	 Train Loss : 0.644468
# Train Epoch: 1[163520/240635(68%)]	 Train Loss : 0.569829
# Train Epoch: 1[163840/240635(68%)]	 Train Loss : 0.667249
# Train Epoch: 1[164160/240635(68%)]	 Train Loss : 0.567240
# Train Epoch: 1[164480/240635(68%)]	 Train Loss : 0.623865
# Train Epoch: 1[164800/240635(68%)]	 Train Loss : 0.591294
# Train Epoch: 1[165120/240635(69%)]	 Train Loss : 0.681402
# Train Epoch: 1[165440/240635(69%)]	 Train Loss : 0.603917
# Train Epoch: 1[165760/240635(69%)]	 Train Loss : 0.752650
# Train Epoch: 1[166080/240635(69%)]	 Train Loss : 0.657066
# Train Epoch: 1[166400/240635(69%)]	 Train Loss : 0.661929
# Train Epoch: 1[166720/240635(69%)]	 Train Loss : 0.660057
# Train Epoch: 1[167040/240635(69%)]	 Train Loss : 0.636855
# Train Epoch: 1[167360/240635(70%)]	 Train Loss : 0.640278
# Train Epoch: 1[167680/240635(70%)]	 Train Loss : 0.551375
# Train Epoch: 1[168000/240635(70%)]	 Train Loss : 0.595042
# Train Epoch: 1[168320/240635(70%)]	 Train Loss : 0.732404
# Train Epoch: 1[168640/240635(70%)]	 Train Loss : 0.704664
# Train Epoch: 1[168960/240635(70%)]	 Train Loss : 0.579482
# Train Epoch: 1[169280/240635(70%)]	 Train Loss : 0.679077
# Train Epoch: 1[169600/240635(70%)]	 Train Loss : 0.622745
# Train Epoch: 1[169920/240635(71%)]	 Train Loss : 0.642535
# Train Epoch: 1[170240/240635(71%)]	 Train Loss : 0.586228
# Train Epoch: 1[170560/240635(71%)]	 Train Loss : 0.558949
# Train Epoch: 1[170880/240635(71%)]	 Train Loss : 0.560095
# Train Epoch: 1[171200/240635(71%)]	 Train Loss : 0.583137
# Train Epoch: 1[171520/240635(71%)]	 Train Loss : 0.682999
# Train Epoch: 1[171840/240635(71%)]	 Train Loss : 0.614090
# Train Epoch: 1[172160/240635(72%)]	 Train Loss : 0.607888
# Train Epoch: 1[172480/240635(72%)]	 Train Loss : 0.582629
# Train Epoch: 1[172800/240635(72%)]	 Train Loss : 0.598051
# Train Epoch: 1[173120/240635(72%)]	 Train Loss : 0.572993
# Train Epoch: 1[173440/240635(72%)]	 Train Loss : 0.538519
# Train Epoch: 1[173760/240635(72%)]	 Train Loss : 0.643992
# Train Epoch: 1[174080/240635(72%)]	 Train Loss : 0.646682
# Train Epoch: 1[174400/240635(72%)]	 Train Loss : 0.616587
# Train Epoch: 1[174720/240635(73%)]	 Train Loss : 0.648382
# Train Epoch: 1[175040/240635(73%)]	 Train Loss : 0.568714
# Train Epoch: 1[175360/240635(73%)]	 Train Loss : 0.610014
# Train Epoch: 1[175680/240635(73%)]	 Train Loss : 0.535482
# Train Epoch: 1[176000/240635(73%)]	 Train Loss : 0.614859
# Train Epoch: 1[176320/240635(73%)]	 Train Loss : 0.530442
# Train Epoch: 1[176640/240635(73%)]	 Train Loss : 0.612130
# Train Epoch: 1[176960/240635(74%)]	 Train Loss : 0.553710
# Train Epoch: 1[177280/240635(74%)]	 Train Loss : 0.707551
# Train Epoch: 1[177600/240635(74%)]	 Train Loss : 0.580374
# Train Epoch: 1[177920/240635(74%)]	 Train Loss : 0.649232
# Train Epoch: 1[178240/240635(74%)]	 Train Loss : 0.613692
# Train Epoch: 1[178560/240635(74%)]	 Train Loss : 0.655348
# Train Epoch: 1[178880/240635(74%)]	 Train Loss : 0.515600
# Train Epoch: 1[179200/240635(74%)]	 Train Loss : 0.605092
# Train Epoch: 1[179520/240635(75%)]	 Train Loss : 0.598563
# Train Epoch: 1[179840/240635(75%)]	 Train Loss : 0.585255
# Train Epoch: 1[180160/240635(75%)]	 Train Loss : 0.582505
# Train Epoch: 1[180480/240635(75%)]	 Train Loss : 0.602848
# Train Epoch: 1[180800/240635(75%)]	 Train Loss : 0.649090
# Train Epoch: 1[181120/240635(75%)]	 Train Loss : 0.607880
# Train Epoch: 1[181440/240635(75%)]	 Train Loss : 0.585004
# Train Epoch: 1[181760/240635(76%)]	 Train Loss : 0.622492
# Train Epoch: 1[182080/240635(76%)]	 Train Loss : 0.579970
# Train Epoch: 1[182400/240635(76%)]	 Train Loss : 0.597684
# Train Epoch: 1[182720/240635(76%)]	 Train Loss : 0.585009
# Train Epoch: 1[183040/240635(76%)]	 Train Loss : 0.613905
# Train Epoch: 1[183360/240635(76%)]	 Train Loss : 0.544857
# Train Epoch: 1[183680/240635(76%)]	 Train Loss : 0.604678
# Train Epoch: 1[184000/240635(76%)]	 Train Loss : 0.579503
# Train Epoch: 1[184320/240635(77%)]	 Train Loss : 0.649095
# Train Epoch: 1[184640/240635(77%)]	 Train Loss : 0.603196
# Train Epoch: 1[184960/240635(77%)]	 Train Loss : 0.615164
# Train Epoch: 1[185280/240635(77%)]	 Train Loss : 0.674206
# Train Epoch: 1[185600/240635(77%)]	 Train Loss : 0.616866
# Train Epoch: 1[185920/240635(77%)]	 Train Loss : 0.585765
# Train Epoch: 1[186240/240635(77%)]	 Train Loss : 0.570173
# Train Epoch: 1[186560/240635(78%)]	 Train Loss : 0.622638
# Train Epoch: 1[186880/240635(78%)]	 Train Loss : 0.662429
# Train Epoch: 1[187200/240635(78%)]	 Train Loss : 0.734262
# Train Epoch: 1[187520/240635(78%)]	 Train Loss : 0.601014
# Train Epoch: 1[187840/240635(78%)]	 Train Loss : 0.565622
# Train Epoch: 1[188160/240635(78%)]	 Train Loss : 0.619114
# Train Epoch: 1[188480/240635(78%)]	 Train Loss : 0.651299
# Train Epoch: 1[188800/240635(78%)]	 Train Loss : 0.599625
# Train Epoch: 1[189120/240635(79%)]	 Train Loss : 0.622338
# Train Epoch: 1[189440/240635(79%)]	 Train Loss : 0.558283
# Train Epoch: 1[189760/240635(79%)]	 Train Loss : 0.599613
# Train Epoch: 1[190080/240635(79%)]	 Train Loss : 0.586884
# Train Epoch: 1[190400/240635(79%)]	 Train Loss : 0.597637
# Train Epoch: 1[190720/240635(79%)]	 Train Loss : 0.685871
# Train Epoch: 1[191040/240635(79%)]	 Train Loss : 0.650889
# Train Epoch: 1[191360/240635(80%)]	 Train Loss : 0.629772
# Train Epoch: 1[191680/240635(80%)]	 Train Loss : 0.582511
# Train Epoch: 1[192000/240635(80%)]	 Train Loss : 0.595349
# Train Epoch: 1[192320/240635(80%)]	 Train Loss : 0.651717
# Train Epoch: 1[192640/240635(80%)]	 Train Loss : 0.551262
# Train Epoch: 1[192960/240635(80%)]	 Train Loss : 0.672392
# Train Epoch: 1[193280/240635(80%)]	 Train Loss : 0.651795
# Train Epoch: 1[193600/240635(80%)]	 Train Loss : 0.591914
# Train Epoch: 1[193920/240635(81%)]	 Train Loss : 0.581424
# Train Epoch: 1[194240/240635(81%)]	 Train Loss : 0.573124
# Train Epoch: 1[194560/240635(81%)]	 Train Loss : 0.596227
# Train Epoch: 1[194880/240635(81%)]	 Train Loss : 0.599781
# Train Epoch: 1[195200/240635(81%)]	 Train Loss : 0.732417
# Train Epoch: 1[195520/240635(81%)]	 Train Loss : 0.704985
# Train Epoch: 1[195840/240635(81%)]	 Train Loss : 0.610713
# Train Epoch: 1[196160/240635(82%)]	 Train Loss : 0.601858
# Train Epoch: 1[196480/240635(82%)]	 Train Loss : 0.547312
# Train Epoch: 1[196800/240635(82%)]	 Train Loss : 0.675994
# Train Epoch: 1[197120/240635(82%)]	 Train Loss : 0.616277
# Train Epoch: 1[197440/240635(82%)]	 Train Loss : 0.668795
# Train Epoch: 1[197760/240635(82%)]	 Train Loss : 0.602841
# Train Epoch: 1[198080/240635(82%)]	 Train Loss : 0.612285
# Train Epoch: 1[198400/240635(82%)]	 Train Loss : 0.597679
# Train Epoch: 1[198720/240635(83%)]	 Train Loss : 0.547975
# Train Epoch: 1[199040/240635(83%)]	 Train Loss : 0.656260
# Train Epoch: 1[199360/240635(83%)]	 Train Loss : 0.648439
# Train Epoch: 1[199680/240635(83%)]	 Train Loss : 0.547305
# Train Epoch: 1[200000/240635(83%)]	 Train Loss : 0.570166
# Train Epoch: 1[200320/240635(83%)]	 Train Loss : 0.604119
# Train Epoch: 1[200640/240635(83%)]	 Train Loss : 0.627517
# Train Epoch: 1[200960/240635(84%)]	 Train Loss : 0.579736
# Train Epoch: 1[201280/240635(84%)]	 Train Loss : 0.624657
# Train Epoch: 1[201600/240635(84%)]	 Train Loss : 0.585432
# Train Epoch: 1[201920/240635(84%)]	 Train Loss : 0.624449
# Train Epoch: 1[202240/240635(84%)]	 Train Loss : 0.648828
# Train Epoch: 1[202560/240635(84%)]	 Train Loss : 0.582615
# Train Epoch: 1[202880/240635(84%)]	 Train Loss : 0.607870
# Train Epoch: 1[203200/240635(84%)]	 Train Loss : 0.573483
# Train Epoch: 1[203520/240635(85%)]	 Train Loss : 0.565847
# Train Epoch: 1[203840/240635(85%)]	 Train Loss : 0.605118
# Train Epoch: 1[204160/240635(85%)]	 Train Loss : 0.645645
# Train Epoch: 1[204480/240635(85%)]	 Train Loss : 0.589912
# Train Epoch: 1[204800/240635(85%)]	 Train Loss : 0.543103
# Train Epoch: 1[205120/240635(85%)]	 Train Loss : 0.588960
# Train Epoch: 1[205440/240635(85%)]	 Train Loss : 0.612415
# Train Epoch: 1[205760/240635(86%)]	 Train Loss : 0.582763
# Train Epoch: 1[206080/240635(86%)]	 Train Loss : 0.629716
# Train Epoch: 1[206400/240635(86%)]	 Train Loss : 0.636358
# Train Epoch: 1[206720/240635(86%)]	 Train Loss : 0.573116
# Train Epoch: 1[207040/240635(86%)]	 Train Loss : 0.549006
# Train Epoch: 1[207360/240635(86%)]	 Train Loss : 0.600330
# Train Epoch: 1[207680/240635(86%)]	 Train Loss : 0.573475
# Train Epoch: 1[208000/240635(86%)]	 Train Loss : 0.616061
# Train Epoch: 1[208320/240635(87%)]	 Train Loss : 0.647518
# Train Epoch: 1[208640/240635(87%)]	 Train Loss : 0.626989
# Train Epoch: 1[208960/240635(87%)]	 Train Loss : 0.642144
# Train Epoch: 1[209280/240635(87%)]	 Train Loss : 0.617759
# Train Epoch: 1[209600/240635(87%)]	 Train Loss : 0.608489
# Train Epoch: 1[209920/240635(87%)]	 Train Loss : 0.600347
# Train Epoch: 1[210240/240635(87%)]	 Train Loss : 0.560567
# Train Epoch: 1[210560/240635(88%)]	 Train Loss : 0.630595
# Train Epoch: 1[210880/240635(88%)]	 Train Loss : 0.646282
# Train Epoch: 1[211200/240635(88%)]	 Train Loss : 0.616990
# Train Epoch: 1[211520/240635(88%)]	 Train Loss : 0.566239
# Train Epoch: 1[211840/240635(88%)]	 Train Loss : 0.662956
# Train Epoch: 1[212160/240635(88%)]	 Train Loss : 0.582428
# Train Epoch: 1[212480/240635(88%)]	 Train Loss : 0.588614
# Train Epoch: 1[212800/240635(88%)]	 Train Loss : 0.562038
# Train Epoch: 1[213120/240635(89%)]	 Train Loss : 0.536636
# Train Epoch: 1[213440/240635(89%)]	 Train Loss : 0.600230
# Train Epoch: 1[213760/240635(89%)]	 Train Loss : 0.587558
# Train Epoch: 1[214080/240635(89%)]	 Train Loss : 0.588033
# Train Epoch: 1[214400/240635(89%)]	 Train Loss : 0.593677
# Train Epoch: 1[214720/240635(89%)]	 Train Loss : 0.536167
# Train Epoch: 1[215040/240635(89%)]	 Train Loss : 0.580698
# Train Epoch: 1[215360/240635(89%)]	 Train Loss : 0.489837
# Train Epoch: 1[215680/240635(90%)]	 Train Loss : 0.655639
# Train Epoch: 1[216000/240635(90%)]	 Train Loss : 0.581697
# Train Epoch: 1[216320/240635(90%)]	 Train Loss : 0.478370
# Train Epoch: 1[216640/240635(90%)]	 Train Loss : 0.587619
# Train Epoch: 1[216960/240635(90%)]	 Train Loss : 0.558826
# Train Epoch: 1[217280/240635(90%)]	 Train Loss : 0.594182
# Train Epoch: 1[217600/240635(90%)]	 Train Loss : 0.585315
# Train Epoch: 1[217920/240635(91%)]	 Train Loss : 0.624024
# Train Epoch: 1[218240/240635(91%)]	 Train Loss : 0.589586
# Train Epoch: 1[218560/240635(91%)]	 Train Loss : 0.602509
# Train Epoch: 1[218880/240635(91%)]	 Train Loss : 0.551352
# Train Epoch: 1[219200/240635(91%)]	 Train Loss : 0.627227
# Train Epoch: 1[219520/240635(91%)]	 Train Loss : 0.643176
# Train Epoch: 1[219840/240635(91%)]	 Train Loss : 0.655261
# Train Epoch: 1[220160/240635(91%)]	 Train Loss : 0.607556
# Train Epoch: 1[220480/240635(92%)]	 Train Loss : 0.530762
# Train Epoch: 1[220800/240635(92%)]	 Train Loss : 0.615937
# Train Epoch: 1[221120/240635(92%)]	 Train Loss : 0.564040
# Train Epoch: 1[221440/240635(92%)]	 Train Loss : 0.626345
# Train Epoch: 1[221760/240635(92%)]	 Train Loss : 0.630275
# Train Epoch: 1[222080/240635(92%)]	 Train Loss : 0.615812
# Train Epoch: 1[222400/240635(92%)]	 Train Loss : 0.612881
# Train Epoch: 1[222720/240635(93%)]	 Train Loss : 0.589372
# Train Epoch: 1[223040/240635(93%)]	 Train Loss : 0.569157
# Train Epoch: 1[223360/240635(93%)]	 Train Loss : 0.641908
# Train Epoch: 1[223680/240635(93%)]	 Train Loss : 0.608570
# Train Epoch: 1[224000/240635(93%)]	 Train Loss : 0.675693
# Train Epoch: 1[224320/240635(93%)]	 Train Loss : 0.548915
# Train Epoch: 1[224640/240635(93%)]	 Train Loss : 0.612849
# Train Epoch: 1[224960/240635(93%)]	 Train Loss : 0.587040
# Train Epoch: 1[225280/240635(94%)]	 Train Loss : 0.620814
# Train Epoch: 1[225600/240635(94%)]	 Train Loss : 0.613396
# Train Epoch: 1[225920/240635(94%)]	 Train Loss : 0.633081
# Train Epoch: 1[226240/240635(94%)]	 Train Loss : 0.618372
# Train Epoch: 1[226560/240635(94%)]	 Train Loss : 0.597056
# Train Epoch: 1[226880/240635(94%)]	 Train Loss : 0.564742
# Train Epoch: 1[227200/240635(94%)]	 Train Loss : 0.481719
# Train Epoch: 1[227520/240635(95%)]	 Train Loss : 0.597315
# Train Epoch: 1[227840/240635(95%)]	 Train Loss : 0.629776
# Train Epoch: 1[228160/240635(95%)]	 Train Loss : 0.591887
# Train Epoch: 1[228480/240635(95%)]	 Train Loss : 0.599461
# Train Epoch: 1[228800/240635(95%)]	 Train Loss : 0.553805
# Train Epoch: 1[229120/240635(95%)]	 Train Loss : 0.549790
# Train Epoch: 1[229440/240635(95%)]	 Train Loss : 0.550974
# Train Epoch: 1[229760/240635(95%)]	 Train Loss : 0.560003
# Train Epoch: 1[230080/240635(96%)]	 Train Loss : 0.608279
# Train Epoch: 1[230400/240635(96%)]	 Train Loss : 0.603188
# Train Epoch: 1[230720/240635(96%)]	 Train Loss : 0.637066
# Train Epoch: 1[231040/240635(96%)]	 Train Loss : 0.585594
# Train Epoch: 1[231360/240635(96%)]	 Train Loss : 0.550068
# Train Epoch: 1[231680/240635(96%)]	 Train Loss : 0.572814
# Train Epoch: 1[232000/240635(96%)]	 Train Loss : 0.577722
# Train Epoch: 1[232320/240635(97%)]	 Train Loss : 0.637782
# Train Epoch: 1[232640/240635(97%)]	 Train Loss : 0.660622
# Train Epoch: 1[232960/240635(97%)]	 Train Loss : 0.646382
# Train Epoch: 1[233280/240635(97%)]	 Train Loss : 0.560499
# Train Epoch: 1[233600/240635(97%)]	 Train Loss : 0.532333
# Train Epoch: 1[233920/240635(97%)]	 Train Loss : 0.608854
# Train Epoch: 1[234240/240635(97%)]	 Train Loss : 0.610579
# Train Epoch: 1[234560/240635(97%)]	 Train Loss : 0.648807
# Train Epoch: 1[234880/240635(98%)]	 Train Loss : 0.629251
# Train Epoch: 1[235200/240635(98%)]	 Train Loss : 0.617423
# Train Epoch: 1[235520/240635(98%)]	 Train Loss : 0.547888
# Train Epoch: 1[235840/240635(98%)]	 Train Loss : 0.601125
# Train Epoch: 1[236160/240635(98%)]	 Train Loss : 0.573568
# Train Epoch: 1[236480/240635(98%)]	 Train Loss : 0.647562
# Train Epoch: 1[236800/240635(98%)]	 Train Loss : 0.616055
# Train Epoch: 1[237120/240635(99%)]	 Train Loss : 0.574438
# Train Epoch: 1[237440/240635(99%)]	 Train Loss : 0.632371
# Train Epoch: 1[237760/240635(99%)]	 Train Loss : 0.589518
# Train Epoch: 1[238080/240635(99%)]	 Train Loss : 0.574440
# Train Epoch: 1[238400/240635(99%)]	 Train Loss : 0.548567
# Train Epoch: 1[238720/240635(99%)]	 Train Loss : 0.587577
# Train Epoch: 1[239040/240635(99%)]	 Train Loss : 0.533990
# Train Epoch: 1[239360/240635(99%)]	 Train Loss : 0.674686
# Train Epoch: 1[239680/240635(100%)]	 Train Loss : 0.560381
# Train Epoch: 1[240000/240635(100%)]	 Train Loss : 0.546604
# Train Epoch: 1[240320/240635(100%)]	 Train Loss : 0.504165
#
# [Epoch: 1],	 Val Loss : 0.0084,	 Val Accuracy : 80.56 %
#
# Validation loss decreased (inf --> 0.008361).  Saving model ...
# Train Epoch: 2[0/240635(0%)]	 Train Loss : 0.625509
# Train Epoch: 2[320/240635(0%)]	 Train Loss : 0.623555
# Train Epoch: 2[640/240635(0%)]	 Train Loss : 0.514944
# Train Epoch: 2[960/240635(0%)]	 Train Loss : 0.624251
# Train Epoch: 2[1280/240635(1%)]	 Train Loss : 0.522822
# Train Epoch: 2[1600/240635(1%)]	 Train Loss : 0.560094
# Train Epoch: 2[1920/240635(1%)]	 Train Loss : 0.578342
# Train Epoch: 2[2240/240635(1%)]	 Train Loss : 0.513552
# Train Epoch: 2[2560/240635(1%)]	 Train Loss : 0.567358
# Train Epoch: 2[2880/240635(1%)]	 Train Loss : 0.575000
# Train Epoch: 2[3200/240635(1%)]	 Train Loss : 0.561977
# Train Epoch: 2[3520/240635(1%)]	 Train Loss : 0.512858
# Train Epoch: 2[3840/240635(2%)]	 Train Loss : 0.582584
# Train Epoch: 2[4160/240635(2%)]	 Train Loss : 0.584751
# Train Epoch: 2[4480/240635(2%)]	 Train Loss : 0.584720
# Train Epoch: 2[4800/240635(2%)]	 Train Loss : 0.583282
# Train Epoch: 2[5120/240635(2%)]	 Train Loss : 0.595290
# Train Epoch: 2[5440/240635(2%)]	 Train Loss : 0.586442
# Train Epoch: 2[5760/240635(2%)]	 Train Loss : 0.548978
# Train Epoch: 2[6080/240635(3%)]	 Train Loss : 0.537994
# Train Epoch: 2[6400/240635(3%)]	 Train Loss : 0.539617
# Train Epoch: 2[6720/240635(3%)]	 Train Loss : 0.636442
# Train Epoch: 2[7040/240635(3%)]	 Train Loss : 0.516756
# Train Epoch: 2[7360/240635(3%)]	 Train Loss : 0.524327
# Train Epoch: 2[7680/240635(3%)]	 Train Loss : 0.578637
# Train Epoch: 2[8000/240635(3%)]	 Train Loss : 0.547607
# Train Epoch: 2[8320/240635(3%)]	 Train Loss : 0.547451
# Train Epoch: 2[8640/240635(4%)]	 Train Loss : 0.524853
# Train Epoch: 2[8960/240635(4%)]	 Train Loss : 0.556961
# Train Epoch: 2[9280/240635(4%)]	 Train Loss : 0.463390
# Train Epoch: 2[9600/240635(4%)]	 Train Loss : 0.694111
# Train Epoch: 2[9920/240635(4%)]	 Train Loss : 0.577226
# Train Epoch: 2[10240/240635(4%)]	 Train Loss : 0.830034
# Train Epoch: 2[10560/240635(4%)]	 Train Loss : 0.640401
# Train Epoch: 2[10880/240635(5%)]	 Train Loss : 0.471227
# Train Epoch: 2[11200/240635(5%)]	 Train Loss : 0.635657
# Train Epoch: 2[11520/240635(5%)]	 Train Loss : 0.591349
# Train Epoch: 2[11840/240635(5%)]	 Train Loss : 0.679452
# Train Epoch: 2[12160/240635(5%)]	 Train Loss : 0.555814
# Train Epoch: 2[12480/240635(5%)]	 Train Loss : 0.602913
# Train Epoch: 2[12800/240635(5%)]	 Train Loss : 0.557373
# Train Epoch: 2[13120/240635(5%)]	 Train Loss : 0.596664
# Train Epoch: 2[13440/240635(6%)]	 Train Loss : 0.487565
# Train Epoch: 2[13760/240635(6%)]	 Train Loss : 0.563284
# Train Epoch: 2[14080/240635(6%)]	 Train Loss : 0.469422
# Train Epoch: 2[14400/240635(6%)]	 Train Loss : 0.517076
# Train Epoch: 2[14720/240635(6%)]	 Train Loss : 0.569679
# Train Epoch: 2[15040/240635(6%)]	 Train Loss : 0.507768
# Train Epoch: 2[15360/240635(6%)]	 Train Loss : 0.550569
# Train Epoch: 2[15680/240635(7%)]	 Train Loss : 0.569430
# Train Epoch: 2[16000/240635(7%)]	 Train Loss : 0.615204
# Train Epoch: 2[16320/240635(7%)]	 Train Loss : 0.645214
# Train Epoch: 2[16640/240635(7%)]	 Train Loss : 0.608283
# Train Epoch: 2[16960/240635(7%)]	 Train Loss : 0.552362
# Train Epoch: 2[17280/240635(7%)]	 Train Loss : 0.511469
# Train Epoch: 2[17600/240635(7%)]	 Train Loss : 0.633491
# Train Epoch: 2[17920/240635(7%)]	 Train Loss : 0.537291
# Train Epoch: 2[18240/240635(8%)]	 Train Loss : 0.534353
# Train Epoch: 2[18560/240635(8%)]	 Train Loss : 0.524605
# Train Epoch: 2[18880/240635(8%)]	 Train Loss : 0.489708
# Train Epoch: 2[19200/240635(8%)]	 Train Loss : 0.601976
# Train Epoch: 2[19520/240635(8%)]	 Train Loss : 0.584285
# Train Epoch: 2[19840/240635(8%)]	 Train Loss : 0.690334
# Train Epoch: 2[20160/240635(8%)]	 Train Loss : 0.704275
# Train Epoch: 2[20480/240635(9%)]	 Train Loss : 0.609232
# Train Epoch: 2[20800/240635(9%)]	 Train Loss : 0.594612
# Train Epoch: 2[21120/240635(9%)]	 Train Loss : 0.492302
# Train Epoch: 2[21440/240635(9%)]	 Train Loss : 0.580748
# Train Epoch: 2[21760/240635(9%)]	 Train Loss : 0.502220
# Train Epoch: 2[22080/240635(9%)]	 Train Loss : 0.513336
# Train Epoch: 2[22400/240635(9%)]	 Train Loss : 0.592529
# Train Epoch: 2[22720/240635(9%)]	 Train Loss : 0.528782
# Train Epoch: 2[23040/240635(10%)]	 Train Loss : 0.665563
# Train Epoch: 2[23360/240635(10%)]	 Train Loss : 0.499289
# Train Epoch: 2[23680/240635(10%)]	 Train Loss : 0.522844
# Train Epoch: 2[24000/240635(10%)]	 Train Loss : 0.553168
# Train Epoch: 2[24320/240635(10%)]	 Train Loss : 0.615841
# Train Epoch: 2[24640/240635(10%)]	 Train Loss : 0.459138
# Train Epoch: 2[24960/240635(10%)]	 Train Loss : 0.544129
# Train Epoch: 2[25280/240635(11%)]	 Train Loss : 0.559568
# Train Epoch: 2[25600/240635(11%)]	 Train Loss : 0.625857
# Train Epoch: 2[25920/240635(11%)]	 Train Loss : 0.678469
# Train Epoch: 2[26240/240635(11%)]	 Train Loss : 0.581465
# Train Epoch: 2[26560/240635(11%)]	 Train Loss : 0.629759
# ...
# Train Epoch: 38[154560/240635(64%)]	 Train Loss : 0.000053
# Train Epoch: 38[154880/240635(64%)]	 Train Loss : 0.000334
# Train Epoch: 38[155200/240635(64%)]	 Train Loss : 0.000095
# Train Epoch: 38[155520/240635(65%)]	 Train Loss : 0.000109
# Train Epoch: 38[155840/240635(65%)]	 Train Loss : 0.000024
# Train Epoch: 38[156160/240635(65%)]	 Train Loss : 0.000092
# Train Epoch: 38[156480/240635(65%)]	 Train Loss : 0.000122
# Train Epoch: 38[156800/240635(65%)]	 Train Loss : 0.000126
# Train Epoch: 38[157120/240635(65%)]	 Train Loss : 0.000173
# Train Epoch: 38[157440/240635(65%)]	 Train Loss : 0.000036
# Train Epoch: 38[157760/240635(66%)]	 Train Loss : 0.000034
# Train Epoch: 38[158080/240635(66%)]	 Train Loss : 0.000053
# Train Epoch: 38[158400/240635(66%)]	 Train Loss : 0.000038
# Train Epoch: 38[158720/240635(66%)]	 Train Loss : 0.000130
# Train Epoch: 38[159040/240635(66%)]	 Train Loss : 0.000036
# Train Epoch: 38[159360/240635(66%)]	 Train Loss : 0.000269
# Train Epoch: 38[159680/240635(66%)]	 Train Loss : 0.037821
# Train Epoch: 38[160000/240635(66%)]	 Train Loss : 0.042990
# Train Epoch: 38[160320/240635(67%)]	 Train Loss : 0.008139
# Train Epoch: 38[160640/240635(67%)]	 Train Loss : 0.000073
# Train Epoch: 38[160960/240635(67%)]	 Train Loss : 0.001244
# Train Epoch: 38[161280/240635(67%)]	 Train Loss : 0.000142
# Train Epoch: 38[161600/240635(67%)]	 Train Loss : 0.000645
# Train Epoch: 38[161920/240635(67%)]	 Train Loss : 0.000615
# Train Epoch: 38[162240/240635(67%)]	 Train Loss : 0.000721
# Train Epoch: 38[162560/240635(68%)]	 Train Loss : 0.000267
# Train Epoch: 38[162880/240635(68%)]	 Train Loss : 0.000071
# Train Epoch: 38[163200/240635(68%)]	 Train Loss : 0.000380
# Train Epoch: 38[163520/240635(68%)]	 Train Loss : 0.000123
# Train Epoch: 38[163840/240635(68%)]	 Train Loss : 0.000084
# Train Epoch: 38[164160/240635(68%)]	 Train Loss : 0.000182
# Train Epoch: 38[164480/240635(68%)]	 Train Loss : 0.000676
# Train Epoch: 38[164800/240635(68%)]	 Train Loss : 0.001506
# Train Epoch: 38[165120/240635(69%)]	 Train Loss : 0.085654
# Train Epoch: 38[165440/240635(69%)]	 Train Loss : 0.000424
# Train Epoch: 38[165760/240635(69%)]	 Train Loss : 0.001776
# Train Epoch: 38[166080/240635(69%)]	 Train Loss : 0.000296
# Train Epoch: 38[166400/240635(69%)]	 Train Loss : 0.000263
# Train Epoch: 38[166720/240635(69%)]	 Train Loss : 0.000391
# Train Epoch: 38[167040/240635(69%)]	 Train Loss : 0.000553
# Train Epoch: 38[167360/240635(70%)]	 Train Loss : 0.000257
# Train Epoch: 38[167680/240635(70%)]	 Train Loss : 0.000232
# Train Epoch: 38[168000/240635(70%)]	 Train Loss : 0.000053
# Train Epoch: 38[168320/240635(70%)]	 Train Loss : 0.000077
# Train Epoch: 38[168640/240635(70%)]	 Train Loss : 0.000030
# Train Epoch: 38[168960/240635(70%)]	 Train Loss : 0.000035
# Train Epoch: 38[169280/240635(70%)]	 Train Loss : 0.000024
# Train Epoch: 38[169600/240635(70%)]	 Train Loss : 0.000015
# Train Epoch: 38[169920/240635(71%)]	 Train Loss : 0.000254
# Train Epoch: 38[170240/240635(71%)]	 Train Loss : 0.001419
# Train Epoch: 38[170560/240635(71%)]	 Train Loss : 0.000070
# Train Epoch: 38[170880/240635(71%)]	 Train Loss : 0.000049
# Train Epoch: 38[171200/240635(71%)]	 Train Loss : 0.000060
# Train Epoch: 38[171520/240635(71%)]	 Train Loss : 0.000122
# Train Epoch: 38[171840/240635(71%)]	 Train Loss : 0.000041
# Train Epoch: 38[172160/240635(72%)]	 Train Loss : 0.000316
# Train Epoch: 38[172480/240635(72%)]	 Train Loss : 0.000051
# Train Epoch: 38[172800/240635(72%)]	 Train Loss : 0.019105
# Train Epoch: 38[173120/240635(72%)]	 Train Loss : 0.000036
# Train Epoch: 38[173440/240635(72%)]	 Train Loss : 0.000075
# Train Epoch: 38[173760/240635(72%)]	 Train Loss : 0.000651
# Train Epoch: 38[174080/240635(72%)]	 Train Loss : 0.000069
# Train Epoch: 38[174400/240635(72%)]	 Train Loss : 0.000077
# Train Epoch: 38[174720/240635(73%)]	 Train Loss : 0.003261
# Train Epoch: 38[175040/240635(73%)]	 Train Loss : 0.000051
# Train Epoch: 38[175360/240635(73%)]	 Train Loss : 0.000105
# Train Epoch: 38[175680/240635(73%)]	 Train Loss : 0.019430
# Train Epoch: 38[176000/240635(73%)]	 Train Loss : 0.030850
# Train Epoch: 38[176320/240635(73%)]	 Train Loss : 0.004292
# Train Epoch: 38[176640/240635(73%)]	 Train Loss : 0.000211
# Train Epoch: 38[176960/240635(74%)]	 Train Loss : 0.000140
# Train Epoch: 38[177280/240635(74%)]	 Train Loss : 0.000120
# Train Epoch: 38[177600/240635(74%)]	 Train Loss : 0.000033
# Train Epoch: 38[177920/240635(74%)]	 Train Loss : 0.000061
# Train Epoch: 38[178240/240635(74%)]	 Train Loss : 0.000099
# Train Epoch: 38[178560/240635(74%)]	 Train Loss : 0.000022
# Train Epoch: 38[178880/240635(74%)]	 Train Loss : 0.000072
# Train Epoch: 38[179200/240635(74%)]	 Train Loss : 0.000043
# Train Epoch: 38[179520/240635(75%)]	 Train Loss : 0.000026
# Train Epoch: 38[179840/240635(75%)]	 Train Loss : 0.000029
# Train Epoch: 38[180160/240635(75%)]	 Train Loss : 0.000008
# Train Epoch: 38[180480/240635(75%)]	 Train Loss : 0.000082
# Train Epoch: 38[180800/240635(75%)]	 Train Loss : 0.000080
# Train Epoch: 38[181120/240635(75%)]	 Train Loss : 0.000045
# Train Epoch: 38[181440/240635(75%)]	 Train Loss : 0.000078
# Train Epoch: 38[181760/240635(76%)]	 Train Loss : 0.000076
# Train Epoch: 38[182080/240635(76%)]	 Train Loss : 0.001276
# Train Epoch: 38[182400/240635(76%)]	 Train Loss : 0.000199
# Train Epoch: 38[182720/240635(76%)]	 Train Loss : 0.000283
# Train Epoch: 38[183040/240635(76%)]	 Train Loss : 0.000470
# Train Epoch: 38[183360/240635(76%)]	 Train Loss : 0.000144
# Train Epoch: 38[183680/240635(76%)]	 Train Loss : 0.000113
# Train Epoch: 38[184000/240635(76%)]	 Train Loss : 0.000402
# Train Epoch: 38[184320/240635(77%)]	 Train Loss : 0.000150
# Train Epoch: 38[184640/240635(77%)]	 Train Loss : 0.000133
# Train Epoch: 38[184960/240635(77%)]	 Train Loss : 0.000078
# Train Epoch: 38[185280/240635(77%)]	 Train Loss : 0.000164
# Train Epoch: 38[185600/240635(77%)]	 Train Loss : 0.000192
# Train Epoch: 38[185920/240635(77%)]	 Train Loss : 0.000060
# Train Epoch: 38[186240/240635(77%)]	 Train Loss : 0.000056
# Train Epoch: 38[186560/240635(78%)]	 Train Loss : 0.000080
# Train Epoch: 38[186880/240635(78%)]	 Train Loss : 0.000071
# Train Epoch: 38[187200/240635(78%)]	 Train Loss : 0.000173
# Train Epoch: 38[187520/240635(78%)]	 Train Loss : 0.021200
# Train Epoch: 38[187840/240635(78%)]	 Train Loss : 0.002124
# Train Epoch: 38[188160/240635(78%)]	 Train Loss : 0.002770
# Train Epoch: 38[188480/240635(78%)]	 Train Loss : 0.000034
# Train Epoch: 38[188800/240635(78%)]	 Train Loss : 0.000025
# Train Epoch: 38[189120/240635(79%)]	 Train Loss : 0.000099
# Train Epoch: 38[189440/240635(79%)]	 Train Loss : 0.000320
# Train Epoch: 38[189760/240635(79%)]	 Train Loss : 0.002657
# Train Epoch: 38[190080/240635(79%)]	 Train Loss : 0.002477
# Train Epoch: 38[190400/240635(79%)]	 Train Loss : 0.000062
# Train Epoch: 38[190720/240635(79%)]	 Train Loss : 0.000040
# Train Epoch: 38[191040/240635(79%)]	 Train Loss : 0.000965
# Train Epoch: 38[191360/240635(80%)]	 Train Loss : 0.000159
# Train Epoch: 38[191680/240635(80%)]	 Train Loss : 0.000334
# Train Epoch: 38[192000/240635(80%)]	 Train Loss : 0.000185
# Train Epoch: 38[192320/240635(80%)]	 Train Loss : 0.001788
# Train Epoch: 38[192640/240635(80%)]	 Train Loss : 0.000084
# Train Epoch: 38[192960/240635(80%)]	 Train Loss : 0.000161
# Train Epoch: 38[193280/240635(80%)]	 Train Loss : 0.000167
# Train Epoch: 38[193600/240635(80%)]	 Train Loss : 0.000085
# Train Epoch: 38[193920/240635(81%)]	 Train Loss : 0.000122
# Train Epoch: 38[194240/240635(81%)]	 Train Loss : 0.000226
# Train Epoch: 38[194560/240635(81%)]	 Train Loss : 0.000051
# Train Epoch: 38[194880/240635(81%)]	 Train Loss : 0.000160
# Train Epoch: 38[195200/240635(81%)]	 Train Loss : 0.000085
# Train Epoch: 38[195520/240635(81%)]	 Train Loss : 0.017063
# Train Epoch: 38[195840/240635(81%)]	 Train Loss : 0.000246
# Train Epoch: 38[196160/240635(82%)]	 Train Loss : 0.000125
# Train Epoch: 38[196480/240635(82%)]	 Train Loss : 0.016374
# Train Epoch: 38[196800/240635(82%)]	 Train Loss : 0.000681
# Train Epoch: 38[197120/240635(82%)]	 Train Loss : 0.001859
# Train Epoch: 38[197440/240635(82%)]	 Train Loss : 0.000607
# Train Epoch: 38[197760/240635(82%)]	 Train Loss : 0.000425
# Train Epoch: 38[198080/240635(82%)]	 Train Loss : 0.000228
# Train Epoch: 38[198400/240635(82%)]	 Train Loss : 0.000089
# Train Epoch: 38[198720/240635(83%)]	 Train Loss : 0.000084
# Train Epoch: 38[199040/240635(83%)]	 Train Loss : 0.000117
# Train Epoch: 38[199360/240635(83%)]	 Train Loss : 0.000092
# Train Epoch: 38[199680/240635(83%)]	 Train Loss : 0.000055
# Train Epoch: 38[200000/240635(83%)]	 Train Loss : 0.000030
# Train Epoch: 38[200320/240635(83%)]	 Train Loss : 0.000032
# Train Epoch: 38[200640/240635(83%)]	 Train Loss : 0.000024
# Train Epoch: 38[200960/240635(84%)]	 Train Loss : 0.000049
# Train Epoch: 38[201280/240635(84%)]	 Train Loss : 0.000064
# Train Epoch: 38[201600/240635(84%)]	 Train Loss : 0.000047
# Train Epoch: 38[201920/240635(84%)]	 Train Loss : 0.000068
# Train Epoch: 38[202240/240635(84%)]	 Train Loss : 0.000097
# Train Epoch: 38[202560/240635(84%)]	 Train Loss : 0.000055
# Train Epoch: 38[202880/240635(84%)]	 Train Loss : 0.000055
# Train Epoch: 38[203200/240635(84%)]	 Train Loss : 0.000059
# Train Epoch: 38[203520/240635(85%)]	 Train Loss : 0.000028
# Train Epoch: 38[203840/240635(85%)]	 Train Loss : 0.000027
# Train Epoch: 38[204160/240635(85%)]	 Train Loss : 0.000051
# Train Epoch: 38[204480/240635(85%)]	 Train Loss : 0.000063
# Train Epoch: 38[204800/240635(85%)]	 Train Loss : 0.000026
# Train Epoch: 38[205120/240635(85%)]	 Train Loss : 0.000094
# Train Epoch: 38[205440/240635(85%)]	 Train Loss : 0.000024
# Train Epoch: 38[205760/240635(86%)]	 Train Loss : 0.000030
# Train Epoch: 38[206080/240635(86%)]	 Train Loss : 0.000033
# Train Epoch: 38[206400/240635(86%)]	 Train Loss : 0.000032
# Train Epoch: 38[206720/240635(86%)]	 Train Loss : 0.000052
# Train Epoch: 38[207040/240635(86%)]	 Train Loss : 0.000694
# Train Epoch: 38[207360/240635(86%)]	 Train Loss : 0.000079
# Train Epoch: 38[207680/240635(86%)]	 Train Loss : 0.000029
# Train Epoch: 38[208000/240635(86%)]	 Train Loss : 0.000033
# Train Epoch: 38[208320/240635(87%)]	 Train Loss : 0.000100
# Train Epoch: 38[208640/240635(87%)]	 Train Loss : 0.000034
# Train Epoch: 38[208960/240635(87%)]	 Train Loss : 0.000089
# Train Epoch: 38[209280/240635(87%)]	 Train Loss : 0.000089
# Train Epoch: 38[209600/240635(87%)]	 Train Loss : 0.000186
# Train Epoch: 38[209920/240635(87%)]	 Train Loss : 0.000077
# Train Epoch: 38[210240/240635(87%)]	 Train Loss : 0.000036
# Train Epoch: 38[210560/240635(88%)]	 Train Loss : 0.000089
# Train Epoch: 38[210880/240635(88%)]	 Train Loss : 0.000071
# Train Epoch: 38[211200/240635(88%)]	 Train Loss : 0.000017
# Train Epoch: 38[211520/240635(88%)]	 Train Loss : 0.000081
# Train Epoch: 38[211840/240635(88%)]	 Train Loss : 0.000024
# Train Epoch: 38[212160/240635(88%)]	 Train Loss : 0.000036
# Train Epoch: 38[212480/240635(88%)]	 Train Loss : 0.000060
# Train Epoch: 38[212800/240635(88%)]	 Train Loss : 0.000054
# Train Epoch: 38[213120/240635(89%)]	 Train Loss : 0.000107
# Train Epoch: 38[213440/240635(89%)]	 Train Loss : 0.000040
# Train Epoch: 38[213760/240635(89%)]	 Train Loss : 0.000134
# Train Epoch: 38[214080/240635(89%)]	 Train Loss : 0.000040
# Train Epoch: 38[214400/240635(89%)]	 Train Loss : 0.000045
# Train Epoch: 38[214720/240635(89%)]	 Train Loss : 0.000021
# Train Epoch: 38[215040/240635(89%)]	 Train Loss : 0.000050
# Train Epoch: 38[215360/240635(89%)]	 Train Loss : 0.000038
# Train Epoch: 38[215680/240635(90%)]	 Train Loss : 0.000151
# Train Epoch: 38[216000/240635(90%)]	 Train Loss : 0.000029
# Train Epoch: 38[216320/240635(90%)]	 Train Loss : 0.000071
# Train Epoch: 38[216640/240635(90%)]	 Train Loss : 0.000012
# Train Epoch: 38[216960/240635(90%)]	 Train Loss : 0.000016
# Train Epoch: 38[217280/240635(90%)]	 Train Loss : 0.000026
# Train Epoch: 38[217600/240635(90%)]	 Train Loss : 0.000031
# Train Epoch: 38[217920/240635(91%)]	 Train Loss : 0.000008
# Train Epoch: 38[218240/240635(91%)]	 Train Loss : 0.000067
# Train Epoch: 38[218560/240635(91%)]	 Train Loss : 0.000009
# Train Epoch: 38[218880/240635(91%)]	 Train Loss : 0.000046
# Train Epoch: 38[219200/240635(91%)]	 Train Loss : 0.000020
# Train Epoch: 38[219520/240635(91%)]	 Train Loss : 0.000023
# Train Epoch: 38[219840/240635(91%)]	 Train Loss : 0.000022
# Train Epoch: 38[220160/240635(91%)]	 Train Loss : 0.000022
# Train Epoch: 38[220480/240635(92%)]	 Train Loss : 0.000014
# Train Epoch: 38[220800/240635(92%)]	 Train Loss : 0.000026
# Train Epoch: 38[221120/240635(92%)]	 Train Loss : 0.000051
# Train Epoch: 38[221440/240635(92%)]	 Train Loss : 0.000013
# Train Epoch: 38[221760/240635(92%)]	 Train Loss : 0.000037
# Train Epoch: 38[222080/240635(92%)]	 Train Loss : 0.000028
# Train Epoch: 38[222400/240635(92%)]	 Train Loss : 0.000031
# Train Epoch: 38[222720/240635(93%)]	 Train Loss : 0.000038
# Train Epoch: 38[223040/240635(93%)]	 Train Loss : 0.011381
# Train Epoch: 38[223360/240635(93%)]	 Train Loss : 0.000230
# Train Epoch: 38[223680/240635(93%)]	 Train Loss : 0.009635
# Train Epoch: 38[224000/240635(93%)]	 Train Loss : 0.000138
# Train Epoch: 38[224320/240635(93%)]	 Train Loss : 0.000164
# Train Epoch: 38[224640/240635(93%)]	 Train Loss : 0.013585
# Train Epoch: 38[224960/240635(93%)]	 Train Loss : 0.036750
# Train Epoch: 38[225280/240635(94%)]	 Train Loss : 0.001597
# Train Epoch: 38[225600/240635(94%)]	 Train Loss : 0.004291
# Train Epoch: 38[225920/240635(94%)]	 Train Loss : 0.000519
# Train Epoch: 38[226240/240635(94%)]	 Train Loss : 0.000123
# Train Epoch: 38[226560/240635(94%)]	 Train Loss : 0.000135
# Train Epoch: 38[226880/240635(94%)]	 Train Loss : 0.000045
# Train Epoch: 38[227200/240635(94%)]	 Train Loss : 0.002495
# Train Epoch: 38[227520/240635(95%)]	 Train Loss : 0.003833
# Train Epoch: 38[227840/240635(95%)]	 Train Loss : 0.000664
# Train Epoch: 38[228160/240635(95%)]	 Train Loss : 0.000252
# Train Epoch: 38[228480/240635(95%)]	 Train Loss : 0.000285
# Train Epoch: 38[228800/240635(95%)]	 Train Loss : 0.000279
# Train Epoch: 38[229120/240635(95%)]	 Train Loss : 0.001061
# Train Epoch: 38[229440/240635(95%)]	 Train Loss : 0.000906
# Train Epoch: 38[229760/240635(95%)]	 Train Loss : 0.000896
# Train Epoch: 38[230080/240635(96%)]	 Train Loss : 0.000548
# Train Epoch: 38[230400/240635(96%)]	 Train Loss : 0.000464
# Train Epoch: 38[230720/240635(96%)]	 Train Loss : 0.000030
# Train Epoch: 38[231040/240635(96%)]	 Train Loss : 0.000082
# Train Epoch: 38[231360/240635(96%)]	 Train Loss : 0.000087
# Train Epoch: 38[231680/240635(96%)]	 Train Loss : 0.000008
# Train Epoch: 38[232000/240635(96%)]	 Train Loss : 0.000112
# Train Epoch: 38[232320/240635(97%)]	 Train Loss : 0.000019
# Train Epoch: 38[232640/240635(97%)]	 Train Loss : 0.000210
# Train Epoch: 38[232960/240635(97%)]	 Train Loss : 0.066667
# Train Epoch: 38[233280/240635(97%)]	 Train Loss : 0.000045
# Train Epoch: 38[233600/240635(97%)]	 Train Loss : 0.000037
# Train Epoch: 38[233920/240635(97%)]	 Train Loss : 0.000746
# Train Epoch: 38[234240/240635(97%)]	 Train Loss : 0.000502
# Train Epoch: 38[234560/240635(97%)]	 Train Loss : 0.010160
# Train Epoch: 38[234880/240635(98%)]	 Train Loss : 0.000340
# Train Epoch: 38[235200/240635(98%)]	 Train Loss : 0.003283
# Train Epoch: 38[235520/240635(98%)]	 Train Loss : 0.000175
# Train Epoch: 38[235840/240635(98%)]	 Train Loss : 0.001192
# Train Epoch: 38[236160/240635(98%)]	 Train Loss : 0.000232
# Train Epoch: 38[236480/240635(98%)]	 Train Loss : 0.001125
# Train Epoch: 38[236800/240635(98%)]	 Train Loss : 0.000550
# Train Epoch: 38[237120/240635(99%)]	 Train Loss : 0.000527
# Train Epoch: 38[237440/240635(99%)]	 Train Loss : 0.068372
# Train Epoch: 38[237760/240635(99%)]	 Train Loss : 0.073830
# Train Epoch: 38[238080/240635(99%)]	 Train Loss : 0.015818
# Train Epoch: 38[238400/240635(99%)]	 Train Loss : 0.000179
# Train Epoch: 38[238720/240635(99%)]	 Train Loss : 0.054024
# Train Epoch: 38[239040/240635(99%)]	 Train Loss : 0.001477
# Train Epoch: 38[239360/240635(99%)]	 Train Loss : 0.000542
# Train Epoch: 38[239680/240635(100%)]	 Train Loss : 0.140211
# Train Epoch: 38[240000/240635(100%)]	 Train Loss : 0.000678
# Train Epoch: 38[240320/240635(100%)]	 Train Loss : 0.005021
#
# [Epoch: 38],	 Val Loss : 0.0006,	 Val Accuracy : 99.08 %
#
# EarlyStopping counter: 10 out of 10
# Early stopping triggered.

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

def evaluate_2(model, test_loader):
    model.eval()
    test_loss, correct = 0, 0
    all_preds = []
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for image, label in test_loader:
            image, label = image.to(device), label.to(device).long()
            output = model(image)
            loss = criterion(output, label)
            test_loss += loss.item()

            prob = torch.softmax(output, dim=1)[:, 1]  # 클래스 1의 확률
            pred = torch.argmax(output, dim=1)

            all_probs.extend(prob.cpu().numpy())
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(label.cpu().numpy())
            correct += pred.eq(label).sum().item()

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)

    # 🧪 추가 지표 계산
    precision = precision_score(all_labels, all_preds, zero_division=0)
    recall = recall_score(all_labels, all_preds, zero_division=0)
    f1 = f1_score(all_labels, all_preds, zero_division=0)
    try:
        auroc = roc_auc_score(all_labels, all_probs)
    except ValueError:
        auroc = float('nan')  # 클래스 1만 있는 경우 등 예외 처리

    # 🔙 모든 지표 리턴
    return {
        'loss': test_loss,
        'accuracy': test_accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'auroc': auroc
    }

# %%
print("🔍 Final Test Evaluation...")
test_loss, test_acc = evaluate(model, testloader)
re= evaluate_2(model, testloader)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")
print(re)
# Out:
# 🔍 Final Test Evaluation...
# Test Loss: 0.0001, Test Accuracy: 99.87%
# {'loss': 0.0001493688124809299, 'accuracy': 99.87034520588932, 'precision': 0.3870967741935484, 'recall': 0.631578947368421, 'f1': 0.48000000000000004, 'auroc': 0.9219354946758938}
